# %%
# !pip install import_ipynb
import import_ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: import_ipynb in /usr/local/lib/python3.8/dist-packages (0.1.4)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from import_ipynb) (5.7.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.8/dist-packages (from import_ipynb) (7.9.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (57.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (5.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import_ipynb) (1.15.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->import_ipynb) (2.16.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from nbformat->import_ipynb) (5.1.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->import_ipynb) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.19.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import_ipynb) (3.11.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core->nbformat->import_ipynb) (2.5.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->IPython->import_ipynb) (0.7.0)

# %% [markdown]
# ## Test original dataset on model to establish upper bound

# %%
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image
import time 


class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'MNIST'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 256
    self.batch_train = 256
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'



args = myArgs()
args.outer_loop, args.inner_loop = get_loops(args.ipc)
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
args.dsa_param = ParamDiffAug()
args.dsa = True if args.method == 'DSA' else False


channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)

net = get_network(args.model, channel, num_classes, im_size).to(args.device)

net.train()
optimizer_net = torch.optim.SGD(net.parameters(), lr=0.01)  # optimizer_img for synthetic data
optimizer_net.zero_grad()

criterion = nn.CrossEntropyLoss().to(args.device)

num_epochs = 20

trainloader = torch.utils.data.DataLoader(dst_train, batch_size=args.batch_train, shuffle=True, num_workers=0)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_net, num_epochs)

start = time.time()

for i in range(num_epochs):
  loss_avg, acc_avg = epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
  for param_group in optimizer_net.param_groups:
    print("Current learning rate is: {}".format(param_group['lr']))

  print("Epoch[{}/{}]: Loss: {:.4f}, ACC: {:.4f}".format(i+1,num_epochs, loss_avg, acc_avg))
  scheduler.step()

print(time.time() - start)
# Out:
# Current learning rate is: 0.01
# Epoch[1/20]: Loss: 0.5307, ACC: 0.9073
# Current learning rate is: 0.009938441702975689
# Epoch[2/20]: Loss: 0.1495, ACC: 0.9681
# Current learning rate is: 0.009755282581475769
# Epoch[3/20]: Loss: 0.1055, ACC: 0.9756
# Current learning rate is: 0.00945503262094184
# Epoch[4/20]: Loss: 0.0852, ACC: 0.9799
# Current learning rate is: 0.009045084971874739
# Epoch[5/20]: Loss: 0.0728, ACC: 0.9824
# Current learning rate is: 0.008535533905932738
# Epoch[6/20]: Loss: 0.0645, ACC: 0.9843
# Current learning rate is: 0.007938926261462366
# Epoch[7/20]: Loss: 0.0591, ACC: 0.9857
# Current learning rate is: 0.007269952498697735
# Epoch[8/20]: Loss: 0.0545, ACC: 0.9868
# Current learning rate is: 0.006545084971874738
# Epoch[9/20]: Loss: 0.0508, ACC: 0.9875
# Current learning rate is: 0.005782172325201155
# Epoch[10/20]: Loss: 0.0483, ACC: 0.9883
# Current learning rate is: 0.005
# Epoch[11/20]: Loss: 0.0460, ACC: 0.9888
# Current learning rate is: 0.004217827674798847
# Epoch[12/20]: Loss: 0.0442, ACC: 0.9892
# Current learning rate is: 0.0034549150281252636
# Epoch[13/20]: Loss: 0.0428, ACC: 0.9896
# Current learning rate is: 0.0027300475013022664
# Epoch[14/20]: Loss: 0.0415, ACC: 0.9899
# Current learning rate is: 0.0020610737385376348
# Epoch[15/20]: Loss: 0.0407, ACC: 0.9902
# Current learning rate is: 0.0014644660940672626
# Epoch[16/20]: Loss: 0.0401, ACC: 0.9902
# Current learning rate is: 0.0009549150281252633
# Epoch[17/20]: Loss: 0.0396, ACC: 0.9905
# Current learning rate is: 0.0005449673790581611
# Epoch[18/20]: Loss: 0.0392, ACC: 0.9905
# Current learning rate is: 0.00024471741852423234
# Epoch[19/20]: Loss: 0.0391, ACC: 0.9906
# Current learning rate is: 6.15582970243117e-05
# Epoch[20/20]: Loss: 0.0389, ACC: 0.9906
# 259.7410955429077

# %%
testloader = torch.utils.data.DataLoader(dst_test, batch_size=args.batch_train, shuffle=True, num_workers=0)
net.eval()
loss_avg, acc_avg = epoch('test', testloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)

print("Test set: Loss: {:.4f}, ACC: {:.4f}".format(loss_avg, acc_avg))
# Out:
# Test set: Loss: 0.0345, ACC: 0.9906

# %% [markdown]
# ## Dataset distillation with matching gradient

# %%
import os
import time
import copy
import argparse
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug


class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'MNIST'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 256
    self.batch_train = 256
    self.init = 'noise'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'

def main():

    # parser = argparse.ArgumentParser(description='Parameter Processing')
    # parser.add_argument('--method', type=str, default='DC', help='DC/DSA')
    # parser.add_argument('--dataset', type=str, default='CIFAR10', help='dataset')
    # parser.add_argument('--model', type=str, default='ConvNet', help='model')
    # parser.add_argument('--ipc', type=int, default=1, help='image(s) per class')
    # parser.add_argument('--eval_mode', type=str, default='S', help='eval_mode') # S: the same to training model, M: multi architectures,  W: net width, D: net depth, A: activation function, P: pooling layer, N: normalization layer,
    # parser.add_argument('--num_exp', type=int, default=5, help='the number of experiments')
    # parser.add_argument('--num_eval', type=int, default=20, help='the number of evaluating randomly initialized models')
    # parser.add_argument('--epoch_eval_train', type=int, default=300, help='epochs to train a model with synthetic data')
    # parser.add_argument('--Iteration', type=int, default=1000, help='training iterations')
    # parser.add_argument('--lr_img', type=float, default=0.1, help='learning rate for updating synthetic images')
    # parser.add_argument('--lr_net', type=float, default=0.01, help='learning rate for updating network parameters')
    # parser.add_argument('--batch_real', type=int, default=256, help='batch size for real data')
    # parser.add_argument('--batch_train', type=int, default=256, help='batch size for training networks')
    # parser.add_argument('--init', type=str, default='noise', help='noise/real: initialize synthetic images from random noise or randomly sampled real images.')
    # parser.add_argument('--dsa_strategy', type=str, default='None', help='differentiable Siamese augmentation strategy')
    # parser.add_argument('--data_path', type=str, default='data', help='dataset path')
    # parser.add_argument('--save_path', type=str, default='result', help='path to save results')
    # parser.add_argument('--dis_metric', type=str, default='ours', help='distance metric')

    # args = parser.parse_args()
    args = myArgs()
    args.outer_loop, args.inner_loop = get_loops(args.ipc)
    args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
    args.dsa_param = ParamDiffAug()
    args.dsa = True if args.method == 'DSA' else False


    if not os.path.exists(args.data_path):
        os.mkdir(args.data_path)

    if not os.path.exists(args.save_path):
        os.mkdir(args.save_path)

    eval_it_pool = np.arange(0, args.Iteration+1, 20).tolist() if args.eval_mode == 'S' or args.eval_mode == 'SS' else [args.Iteration] # The list of iterations when we evaluate models and record results.
    print('eval_it_pool: ', eval_it_pool)
    channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)
    model_eval_pool = get_eval_pool(args.eval_mode, args.model, args.model)


    accs_all_exps = dict() # record performances of all experiments
    for key in model_eval_pool:
        accs_all_exps[key] = []

    data_save = []


    for exp in range(args.num_exp):
        print('\n================== Exp %d ==================\n '%exp)
        print('Hyper-parameters: \n', args.__dict__)
        print('Evaluation model pool: ', model_eval_pool)

        ''' organize the real dataset '''
        images_all = []
        labels_all = []
        indices_class = [[] for c in range(num_classes)]

        images_all = [torch.unsqueeze(dst_train[i][0], dim=0) for i in range(len(dst_train))]
        labels_all = [dst_train[i][1] for i in range(len(dst_train))]
        for i, lab in enumerate(labels_all):
            indices_class[lab].append(i)
        images_all = torch.cat(images_all, dim=0).to(args.device)
        labels_all = torch.tensor(labels_all, dtype=torch.long, device=args.device)

        for c in range(num_classes):
            print('class c = %d: %d real images'%(c, len(indices_class[c])))

        def get_images(c, n): # get random n images from class c
            idx_shuffle = np.random.permutation(indices_class[c])[:n]
            return images_all[idx_shuffle]

        for ch in range(channel):
            print('real images channel %d, mean = %.4f, std = %.4f'%(ch, torch.mean(images_all[:, ch]), torch.std(images_all[:, ch])))


        ''' initialize the synthetic data '''
        image_syn = torch.randn(size=(num_classes*args.ipc, channel, im_size[0], im_size[1]), dtype=torch.float, requires_grad=True, device=args.device)
        label_syn = torch.tensor([np.ones(args.ipc)*i for i in range(num_classes)], dtype=torch.long, requires_grad=False, device=args.device).view(-1) # [0,0,0, 1,1,1, ..., 9,9,9]

        if args.init == 'real':
            print('initialize synthetic data from random real images')
            for c in range(num_classes):
                image_syn.data[c*args.ipc:(c+1)*args.ipc] = get_images(c, args.ipc).detach().data
        else:
            print('initialize synthetic data from random noise')


        ''' training '''
        optimizer_img = torch.optim.SGD([image_syn, ], lr=args.lr_img, momentum=0.5) # optimizer_img for synthetic data
        optimizer_img.zero_grad()
        criterion = nn.CrossEntropyLoss().to(args.device)
        print('%s training begins'%get_time())

        for it in range(args.Iteration+1):

            ''' Evaluate synthetic data '''
            if it in eval_it_pool:
                for model_eval in model_eval_pool:
                    print('-------------------------\nEvaluation\nmodel_train = %s, model_eval = %s, iteration = %d'%(args.model, model_eval, it))
                    if args.dsa:
                        args.epoch_eval_train = 1000
                        args.dc_aug_param = None
                        print('DSA augmentation strategy: \n', args.dsa_strategy)
                        print('DSA augmentation parameters: \n', args.dsa_param.__dict__)
                    else:
                        args.dc_aug_param = get_daparam(args.dataset, args.model, model_eval, args.ipc) # This augmentation parameter set is only for DC method. It will be muted when args.dsa is True.
                        print('DC augmentation parameters: \n', args.dc_aug_param)

                    if args.dsa or args.dc_aug_param['strategy'] != 'none':
                        args.epoch_eval_train = 1000  # Training with data augmentation needs more epochs.
                    else:
                        args.epoch_eval_train = 300

                    accs = []
                    for it_eval in range(args.num_eval):
                        net_eval = get_network(model_eval, channel, num_classes, im_size).to(args.device) # get a random model
                        image_syn_eval, label_syn_eval = copy.deepcopy(image_syn.detach()), copy.deepcopy(label_syn.detach()) # avoid any unaware modification
                        _, acc_train, acc_test = evaluate_synset(it_eval, net_eval, image_syn_eval, label_syn_eval, testloader, args)
                        accs.append(acc_test)
                    print('Evaluate %d random %s, mean = %.4f std = %.4f\n-------------------------'%(len(accs), model_eval, np.mean(accs), np.std(accs)))

                    if it == args.Iteration: # record the final results
                        accs_all_exps[model_eval] += accs

                ''' visualize and save '''
                save_name = os.path.join(args.save_path, 'vis_%s_%s_%s_%dipc_exp%d_iter%d.png'%(args.method, args.dataset, args.model, args.ipc, exp, it))
                image_syn_vis = copy.deepcopy(image_syn.detach().cpu())
                for ch in range(channel):
                    image_syn_vis[:, ch] = image_syn_vis[:, ch]  * std[ch] + mean[ch]
                image_syn_vis[image_syn_vis<0] = 0.0
                image_syn_vis[image_syn_vis>1] = 1.0
                save_image(image_syn_vis, save_name, nrow=args.ipc) # Trying normalize = True/False may get better visual effects.


            ''' Train synthetic data '''
            net = get_network(args.model, channel, num_classes, im_size).to(args.device) # get a random model
            net.train()
            net_parameters = list(net.parameters())
            optimizer_net = torch.optim.SGD(net.parameters(), lr=args.lr_net)  # optimizer_img for synthetic data
            optimizer_net.zero_grad()
            loss_avg = 0
            args.dc_aug_param = None  # Mute the DC augmentation when learning synthetic data (in inner-loop epoch function) in oder to be consistent with DC paper.


            for ol in range(args.outer_loop):

                ''' freeze the running mu and sigma for BatchNorm layers '''
                # Synthetic data batch, e.g. only 1 image/batch, is too small to obtain stable mu and sigma.
                # So, we calculate and freeze mu and sigma for BatchNorm layer with real data batch ahead.
                # This would make the training with BatchNorm layers easier.

                BN_flag = False
                BNSizePC = 16  # for batch normalization
                for module in net.modules():
                    if 'BatchNorm' in module._get_name(): #BatchNorm
                        BN_flag = True
                if BN_flag:
                    img_real = torch.cat([get_images(c, BNSizePC) for c in range(num_classes)], dim=0)
                    net.train() # for updating the mu, sigma of BatchNorm
                    output_real = net(img_real) # get running mu, sigma
                    for module in net.modules():
                        if 'BatchNorm' in module._get_name():  #BatchNorm
                            module.eval() # fix mu and sigma of every BatchNorm layer


                ''' update synthetic data '''
                loss = torch.tensor(0.0).to(args.device)
                for c in range(num_classes):
                    img_real = get_images(c, args.batch_real)
                    lab_real = torch.ones((img_real.shape[0],), device=args.device, dtype=torch.long) * c
                    img_syn = image_syn[c*args.ipc:(c+1)*args.ipc].reshape((args.ipc, channel, im_size[0], im_size[1]))
                    lab_syn = torch.ones((args.ipc,), device=args.device, dtype=torch.long) * c

                    if args.dsa:
                        seed = int(time.time() * 1000) % 100000
                        img_real = DiffAugment(img_real, args.dsa_strategy, seed=seed, param=args.dsa_param)
                        img_syn = DiffAugment(img_syn, args.dsa_strategy, seed=seed, param=args.dsa_param)

                    output_real = net(img_real)
                    loss_real = criterion(output_real, lab_real)
                    gw_real = torch.autograd.grad(loss_real, net_parameters)
                    gw_real = list((_.detach().clone() for _ in gw_real))

                    output_syn = net(img_syn)
                    loss_syn = criterion(output_syn, lab_syn)
                    gw_syn = torch.autograd.grad(loss_syn, net_parameters, create_graph=True)

                    loss += match_loss(gw_syn, gw_real, args)

                optimizer_img.zero_grad()
                loss.backward()
                optimizer_img.step()
                loss_avg += loss.item()

                if ol == args.outer_loop - 1:
                    break


                ''' update network '''
                image_syn_train, label_syn_train = copy.deepcopy(image_syn.detach()), copy.deepcopy(label_syn.detach())  # avoid any unaware modification
                dst_syn_train = TensorDataset(image_syn_train, label_syn_train)
                trainloader = torch.utils.data.DataLoader(dst_syn_train, batch_size=args.batch_train, shuffle=True, num_workers=0)
                for il in range(args.inner_loop):
                    epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)


            loss_avg /= (num_classes*args.outer_loop)

            if it%10 == 0:
                print('%s iter = %04d, loss = %.4f' % (get_time(), it, loss_avg))

            if it == args.Iteration: # only record the final results
                data_save.append([copy.deepcopy(image_syn.detach().cpu()), copy.deepcopy(label_syn.detach().cpu())])
                torch.save({'data': data_save, 'accs_all_exps': accs_all_exps, }, os.path.join(args.save_path, 'res_%s_%s_%s_%dipc.pt'%(args.method, args.dataset, args.model, args.ipc)))


    print('\n==================== Final Results ====================\n')
    for key in model_eval_pool:
        accs = accs_all_exps[key]
        print('Run %d experiments, train on %s, evaluate %d random %s, mean  = %.2f%%  std = %.2f%%'%(args.num_exp, args.model, len(accs), key, np.mean(accs)*100, np.std(accs)*100))

# %%
main()
# Out:
# eval_it_pool:  [0, 20, 40, 60, 80, 100]
#
# ================== Exp 0 ==================
#
# Hyper-parameters:
#  {'method': 'DC', 'dataset': 'MNIST', 'model': 'ConvNet', 'ipc': 10, 'eval_mode': 'S', 'num_exp': 1, 'num_eval': 5, 'epoch_eval_train': 300, 'Iteration': 100, 'lr_img': 0.1, 'lr_net': 0.01, 'batch_real': 256, 'batch_train': 256, 'init': 'real', 'dsa_strategy': 'None', 'data_path': 'data', 'save_path': 'result', 'dis_metric': 'ours', 'outer_loop': 10, 'inner_loop': 50, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7efe3ea05750>, 'dsa': False}
# Evaluation model pool:  ['ConvNet']
# class c = 0: 5923 real images
# class c = 1: 6742 real images
# class c = 2: 5958 real images
# class c = 3: 6131 real images
# class c = 4: 5842 real images
# class c = 5: 5421 real images
# class c = 6: 5918 real images
# class c = 7: 6265 real images
# class c = 8: 5851 real images
# class c = 9: 5949 real images
# real images channel 0, mean = -0.0001, std = 1.0000
# initialize synthetic data from random real images
# [2022-11-26 00:05:57] training begins
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 0
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-26 00:06:38] Evaluate_00: epoch = 1000 train time = 38 s train loss = 0.003634 train acc = 1.0000, test acc = 0.9461
# [2022-11-26 00:07:17] Evaluate_01: epoch = 1000 train time = 37 s train loss = 0.004909 train acc = 1.0000, test acc = 0.9438
# [2022-11-26 00:07:57] Evaluate_02: epoch = 1000 train time = 37 s train loss = 0.008056 train acc = 1.0000, test acc = 0.9454
# [2022-11-26 00:08:36] Evaluate_03: epoch = 1000 train time = 37 s train loss = 0.006333 train acc = 1.0000, test acc = 0.9429
# [2022-11-26 00:09:15] Evaluate_04: epoch = 1000 train time = 36 s train loss = 0.005258 train acc = 1.0000, test acc = 0.9448
# Evaluate 5 random ConvNet, mean = 0.9446 std = 0.0011
# -------------------------
# [2022-11-26 00:09:24] iter = 0000, loss = 51.1785
# [2022-11-26 00:11:02] iter = 0010, loss = 38.1425
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 20
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-26 00:13:05] Evaluate_00: epoch = 1000 train time = 35 s train loss = 0.007289 train acc = 1.0000, test acc = 0.9696
# [2022-11-26 00:13:43] Evaluate_01: epoch = 1000 train time = 35 s train loss = 0.008207 train acc = 1.0000, test acc = 0.9640
# [2022-11-26 00:14:20] Evaluate_02: epoch = 1000 train time = 35 s train loss = 0.006449 train acc = 1.0000, test acc = 0.9687
# [2022-11-26 00:14:57] Evaluate_03: epoch = 1000 train time = 35 s train loss = 0.006561 train acc = 1.0000, test acc = 0.9634
# [2022-11-26 00:15:35] Evaluate_04: epoch = 1000 train time = 35 s train loss = 0.005742 train acc = 1.0000, test acc = 0.9667
# Evaluate 5 random ConvNet, mean = 0.9665 std = 0.0025
# -------------------------
# [2022-11-26 00:15:45] iter = 0020, loss = 36.7270
# [2022-11-26 00:17:21] iter = 0030, loss = 37.5398
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 40
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-26 00:19:24] Evaluate_00: epoch = 1000 train time = 34 s train loss = 0.006767 train acc = 1.0000, test acc = 0.9698
# [2022-11-26 00:20:01] Evaluate_01: epoch = 1000 train time = 35 s train loss = 0.008397 train acc = 1.0000, test acc = 0.9666
# [2022-11-26 00:20:39] Evaluate_02: epoch = 1000 train time = 35 s train loss = 0.009383 train acc = 1.0000, test acc = 0.9680
# [2022-11-26 00:21:16] Evaluate_03: epoch = 1000 train time = 35 s train loss = 0.008438 train acc = 1.0000, test acc = 0.9660
# [2022-11-26 00:21:53] Evaluate_04: epoch = 1000 train time = 35 s train loss = 0.014788 train acc = 1.0000, test acc = 0.9679
# Evaluate 5 random ConvNet, mean = 0.9677 std = 0.0013
# -------------------------
# [2022-11-26 00:22:03] iter = 0040, loss = 36.4738
# [2022-11-26 00:23:39] iter = 0050, loss = 35.7902
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 60
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-26 00:25:45] Evaluate_00: epoch = 1000 train time = 36 s train loss = 0.005565 train acc = 1.0000, test acc = 0.9702
# [2022-11-26 00:26:25] Evaluate_01: epoch = 1000 train time = 37 s train loss = 0.010851 train acc = 1.0000, test acc = 0.9674
# [2022-11-26 00:27:04] Evaluate_02: epoch = 1000 train time = 36 s train loss = 0.008534 train acc = 1.0000, test acc = 0.9681
# [2022-11-26 00:27:42] Evaluate_03: epoch = 1000 train time = 35 s train loss = 0.009852 train acc = 1.0000, test acc = 0.9671
# [2022-11-26 00:28:19] Evaluate_04: epoch = 1000 train time = 35 s train loss = 0.015666 train acc = 1.0000, test acc = 0.9679
# Evaluate 5 random ConvNet, mean = 0.9681 std = 0.0011
# -------------------------
# [2022-11-26 00:28:29] iter = 0060, loss = 36.8356
# [2022-11-26 00:30:05] iter = 0070, loss = 34.7574
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 80
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-26 00:32:09] Evaluate_00: epoch = 1000 train time = 35 s train loss = 0.012386 train acc = 1.0000, test acc = 0.9701
# [2022-11-26 00:32:46] Evaluate_01: epoch = 1000 train time = 35 s train loss = 0.011465 train acc = 1.0000, test acc = 0.9690
# [2022-11-26 00:33:24] Evaluate_02: epoch = 1000 train time = 35 s train loss = 0.010277 train acc = 1.0000, test acc = 0.9711
# [2022-11-26 00:34:01] Evaluate_03: epoch = 1000 train time = 35 s train loss = 0.005632 train acc = 1.0000, test acc = 0.9718
# [2022-11-26 00:34:38] Evaluate_04: epoch = 1000 train time = 35 s train loss = 0.007931 train acc = 1.0000, test acc = 0.9707
# Evaluate 5 random ConvNet, mean = 0.9705 std = 0.0009
# -------------------------
# [2022-11-26 00:34:48] iter = 0080, loss = 34.6930
# [2022-11-26 00:36:24] iter = 0090, loss = 35.1284
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 100
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-26 00:38:28] Evaluate_00: epoch = 1000 train time = 34 s train loss = 0.009012 train acc = 1.0000, test acc = 0.9708
# [2022-11-26 00:39:05] Evaluate_01: epoch = 1000 train time = 35 s train loss = 0.008090 train acc = 1.0000, test acc = 0.9710
# [2022-11-26 00:39:42] Evaluate_02: epoch = 1000 train time = 35 s train loss = 0.008007 train acc = 1.0000, test acc = 0.9715
# [2022-11-26 00:40:19] Evaluate_03: epoch = 1000 train time = 35 s train loss = 0.009296 train acc = 1.0000, test acc = 0.9703
# [2022-11-26 00:40:56] Evaluate_04: epoch = 1000 train time = 35 s train loss = 0.009914 train acc = 1.0000, test acc = 0.9726
# Evaluate 5 random ConvNet, mean = 0.9712 std = 0.0008
# -------------------------
# [2022-11-26 00:41:06] iter = 0100, loss = 34.6035
#
# ==================== Final Results ====================
#
# Run 1 experiments, train on ConvNet, evaluate 5 random ConvNet, mean  = 97.12%  std = 0.08%

# %%
main()
# Out:
# eval_it_pool:  [0, 20, 40, 60, 80, 100]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Attention: Here I will replace BN with IN in evaluation, as the synthetic set is too small to measure BN hyper-parameters.
#
# ================== Exp 0 ==================
#
# Hyper-parameters:
#  {'method': 'DC', 'dataset': 'CIFAR10', 'model': 'ResNet18BN_AP', 'ipc': 10, 'eval_mode': 'S', 'num_exp': 1, 'num_eval': 5, 'epoch_eval_train': 300, 'Iteration': 100, 'lr_img': 0.1, 'lr_net': 0.01, 'batch_real': 256, 'batch_train': 256, 'init': 'real', 'dsa_strategy': 'None', 'data_path': 'data', 'save_path': 'result', 'dis_metric': 'ours', 'outer_loop': 10, 'inner_loop': 50, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7f8a44d56e50>, 'dsa': False}
# Evaluation model pool:  ['ResNet18']
# class c = 0: 5000 real images
# class c = 1: 5000 real images
# class c = 2: 5000 real images
# class c = 3: 5000 real images
# class c = 4: 5000 real images
# class c = 5: 5000 real images
# class c = 6: 5000 real images
# class c = 7: 5000 real images
# class c = 8: 5000 real images
# class c = 9: 5000 real images
# real images channel 0, mean = -0.0000, std = 1.2211
# real images channel 1, mean = -0.0002, std = 1.2211
# real images channel 2, mean = 0.0002, std = 1.3014
# initialize synthetic data from random real images
# [2022-11-26 03:01:18] training begins
# -------------------------
# Evaluation
# model_train = ResNet18BN_AP, model_eval = ResNet18, iteration = 0
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'none'}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:112: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
# [2022-11-26 03:01:56] Evaluate_00: epoch = 0300 train time = 33 s train loss = 0.005744 train acc = 1.0000, test acc = 0.1986
# [2022-11-26 03:02:29] Evaluate_01: epoch = 0300 train time = 27 s train loss = 0.005755 train acc = 1.0000, test acc = 0.2089
# [2022-11-26 03:03:02] Evaluate_02: epoch = 0300 train time = 28 s train loss = 0.005846 train acc = 1.0000, test acc = 0.1960
# [2022-11-26 03:03:35] Evaluate_03: epoch = 0300 train time = 28 s train loss = 0.005902 train acc = 1.0000, test acc = 0.2062
# [2022-11-26 03:04:09] Evaluate_04: epoch = 0300 train time = 29 s train loss = 0.005653 train acc = 1.0000, test acc = 0.2030
# Evaluate 5 random ResNet18, mean = 0.2025 std = 0.0047
# -------------------------
# [2022-11-26 03:05:30] iter = 0000, loss = 1895.7798
# [2022-11-26 03:18:59] iter = 0010, loss = 2683.2079
# -------------------------
# Evaluation
# model_train = ResNet18BN_AP, model_eval = ResNet18, iteration = 20
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'none'}
# [2022-11-26 03:31:42] Evaluate_00: epoch = 0300 train time = 29 s train loss = 0.006080 train acc = 1.0000, test acc = 0.1187
# [2022-11-26 03:32:16] Evaluate_01: epoch = 0300 train time = 29 s train loss = 0.006057 train acc = 1.0000, test acc = 0.1240
# [2022-11-26 03:32:50] Evaluate_02: epoch = 0300 train time = 29 s train loss = 0.005942 train acc = 1.0000, test acc = 0.1355
# [2022-11-26 03:33:24] Evaluate_03: epoch = 0300 train time = 29 s train loss = 0.006009 train acc = 1.0000, test acc = 0.1224
# [2022-11-26 03:33:58] Evaluate_04: epoch = 0300 train time = 29 s train loss = 0.005985 train acc = 1.0000, test acc = 0.1295
# Evaluate 5 random ResNet18, mean = 0.1260 std = 0.0059
# -------------------------
# [2022-11-26 03:35:19] iter = 0020, loss = 2957.5407
# [2022-11-26 03:48:50] iter = 0030, loss = 3277.7272
# -------------------------
# Evaluation
# model_train = ResNet18BN_AP, model_eval = ResNet18, iteration = 40
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'none'}
# [2022-11-26 04:01:32] Evaluate_00: epoch = 0300 train time = 29 s train loss = 0.006038 train acc = 1.0000, test acc = 0.1200
# [2022-11-26 04:02:07] Evaluate_01: epoch = 0300 train time = 29 s train loss = 0.006015 train acc = 1.0000, test acc = 0.1105
# [2022-11-26 04:02:41] Evaluate_02: epoch = 0300 train time = 29 s train loss = 0.005995 train acc = 1.0000, test acc = 0.1176
# [2022-11-26 04:03:15] Evaluate_03: epoch = 0300 train time = 29 s train loss = 0.006011 train acc = 1.0000, test acc = 0.1236
# [2022-11-26 04:03:49] Evaluate_04: epoch = 0300 train time = 29 s train loss = 0.006058 train acc = 1.0000, test acc = 0.1249
# Evaluate 5 random ResNet18, mean = 0.1193 std = 0.0051
# -------------------------
# [2022-11-26 04:05:10] iter = 0040, loss = 2889.0939
# [2022-11-26 04:18:39] iter = 0050, loss = 2716.9702
# -------------------------
# Evaluation
# model_train = ResNet18BN_AP, model_eval = ResNet18, iteration = 60
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'none'}
# [2022-11-26 04:31:21] Evaluate_00: epoch = 0300 train time = 29 s train loss = 0.006015 train acc = 1.0000, test acc = 0.1166
# [2022-11-26 04:31:56] Evaluate_01: epoch = 0300 train time = 29 s train loss = 0.005815 train acc = 1.0000, test acc = 0.1237
# [2022-11-26 04:32:30] Evaluate_02: epoch = 0300 train time = 29 s train loss = 0.006092 train acc = 1.0000, test acc = 0.1221
# [2022-11-26 04:33:04] Evaluate_03: epoch = 0300 train time = 29 s train loss = 0.006004 train acc = 1.0000, test acc = 0.1214
# [2022-11-26 04:33:38] Evaluate_04: epoch = 0300 train time = 29 s train loss = 0.006059 train acc = 1.0000, test acc = 0.1148
# Evaluate 5 random ResNet18, mean = 0.1197 std = 0.0034
# -------------------------
# [2022-11-26 04:34:59] iter = 0060, loss = 2631.6314
# [2022-11-26 04:48:29] iter = 0070, loss = 2844.5502
# -------------------------
# Evaluation
# model_train = ResNet18BN_AP, model_eval = ResNet18, iteration = 80
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'none'}
# [2022-11-26 05:01:11] Evaluate_00: epoch = 0300 train time = 29 s train loss = 0.006101 train acc = 1.0000, test acc = 0.1277
# [2022-11-26 05:01:45] Evaluate_01: epoch = 0300 train time = 29 s train loss = 0.006048 train acc = 1.0000, test acc = 0.1267
# [2022-11-26 05:02:19] Evaluate_02: epoch = 0300 train time = 29 s train loss = 0.006079 train acc = 1.0000, test acc = 0.1254
# [2022-11-26 05:02:53] Evaluate_03: epoch = 0300 train time = 29 s train loss = 0.006031 train acc = 1.0000, test acc = 0.1227
# [2022-11-26 05:03:27] Evaluate_04: epoch = 0300 train time = 29 s train loss = 0.006040 train acc = 1.0000, test acc = 0.1231
# Evaluate 5 random ResNet18, mean = 0.1251 std = 0.0020
# -------------------------
# [2022-11-26 05:04:48] iter = 0080, loss = 3336.8665
# [2022-11-26 05:18:18] iter = 0090, loss = 3082.1822
# -------------------------
# Evaluation
# model_train = ResNet18BN_AP, model_eval = ResNet18, iteration = 100
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'none'}
# [2022-11-26 05:31:01] Evaluate_00: epoch = 0300 train time = 29 s train loss = 0.006083 train acc = 1.0000, test acc = 0.1281
# [2022-11-26 05:31:35] Evaluate_01: epoch = 0300 train time = 29 s train loss = 0.006124 train acc = 1.0000, test acc = 0.1310
# [2022-11-26 05:32:09] Evaluate_02: epoch = 0300 train time = 29 s train loss = 0.006090 train acc = 1.0000, test acc = 0.1351
# [2022-11-26 05:32:43] Evaluate_03: epoch = 0300 train time = 29 s train loss = 0.006023 train acc = 1.0000, test acc = 0.1280
# [2022-11-26 05:33:17] Evaluate_04: epoch = 0300 train time = 29 s train loss = 0.006103 train acc = 1.0000, test acc = 0.1343
# Evaluate 5 random ResNet18, mean = 0.1313 std = 0.0030
# -------------------------
# [2022-11-26 05:34:38] iter = 0100, loss = 2886.2388
#
# ==================== Final Results ====================
#
# Run 1 experiments, train on ResNet18BN_AP, evaluate 5 random ResNet18, mean  = 13.13%  std = 0.30%

# %%
main()
# Out:
# eval_it_pool:  [0, 20, 40, 60, 80, 100]
#
# ================== Exp 0 ==================
#
# Hyper-parameters:
#  {'method': 'DC', 'dataset': 'MNIST', 'model': 'ConvNet', 'ipc': 10, 'eval_mode': 'S', 'num_exp': 1, 'num_eval': 5, 'epoch_eval_train': 300, 'Iteration': 100, 'lr_img': 0.1, 'lr_net': 0.01, 'batch_real': 256, 'batch_train': 256, 'init': 'noise', 'dsa_strategy': 'None', 'data_path': 'data', 'save_path': 'result', 'dis_metric': 'ours', 'outer_loop': 10, 'inner_loop': 50, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7fc13e328210>, 'dsa': False}
# Evaluation model pool:  ['ConvNet']
# class c = 0: 5923 real images
# class c = 1: 6742 real images
# class c = 2: 5958 real images
# class c = 3: 6131 real images
# class c = 4: 5842 real images
# class c = 5: 5421 real images
# class c = 6: 5918 real images
# class c = 7: 6265 real images
# class c = 8: 5851 real images
# class c = 9: 5949 real images
# real images channel 0, mean = -0.0001, std = 1.0000
# initialize synthetic data from random noise
# [2022-11-27 16:30:24] training begins
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 0
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:112: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
# [2022-11-27 16:31:00] Evaluate_00: epoch = 1000 train time = 34 s train loss = 0.012398 train acc = 1.0000, test acc = 0.0855
# [2022-11-27 16:31:37] Evaluate_01: epoch = 1000 train time = 35 s train loss = 0.008104 train acc = 1.0000, test acc = 0.0779
# [2022-11-27 16:32:14] Evaluate_02: epoch = 1000 train time = 34 s train loss = 0.019059 train acc = 1.0000, test acc = 0.0687
# [2022-11-27 16:32:51] Evaluate_03: epoch = 1000 train time = 34 s train loss = 0.010604 train acc = 1.0000, test acc = 0.0666
# [2022-11-27 16:33:28] Evaluate_04: epoch = 1000 train time = 34 s train loss = 0.010578 train acc = 1.0000, test acc = 0.0496
# Evaluate 5 random ConvNet, mean = 0.0697 std = 0.0121
# -------------------------
# [2022-11-27 16:33:37] iter = 0000, loss = 221.2675
# [2022-11-27 16:35:10] iter = 0010, loss = 93.1256
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 20
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-27 16:37:10] Evaluate_00: epoch = 1000 train time = 34 s train loss = 0.007271 train acc = 1.0000, test acc = 0.8890
# [2022-11-27 16:37:46] Evaluate_01: epoch = 1000 train time = 34 s train loss = 0.010688 train acc = 1.0000, test acc = 0.8793
# [2022-11-27 16:38:23] Evaluate_02: epoch = 1000 train time = 34 s train loss = 0.009390 train acc = 1.0000, test acc = 0.8807
# [2022-11-27 16:39:00] Evaluate_03: epoch = 1000 train time = 35 s train loss = 0.016036 train acc = 1.0000, test acc = 0.8871
# [2022-11-27 16:39:37] Evaluate_04: epoch = 1000 train time = 34 s train loss = 0.012489 train acc = 1.0000, test acc = 0.8740
# Evaluate 5 random ConvNet, mean = 0.8820 std = 0.0054
# -------------------------
# [2022-11-27 16:39:46] iter = 0020, loss = 68.1836
# [2022-11-27 16:41:19] iter = 0030, loss = 61.3109
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 40
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-27 16:43:19] Evaluate_00: epoch = 1000 train time = 34 s train loss = 0.010591 train acc = 1.0000, test acc = 0.9394
# [2022-11-27 16:43:56] Evaluate_01: epoch = 1000 train time = 34 s train loss = 0.013091 train acc = 1.0000, test acc = 0.9424
# [2022-11-27 16:44:33] Evaluate_02: epoch = 1000 train time = 34 s train loss = 0.005652 train acc = 1.0000, test acc = 0.9417
# [2022-11-27 16:45:09] Evaluate_03: epoch = 1000 train time = 34 s train loss = 0.012082 train acc = 1.0000, test acc = 0.9444
# [2022-11-27 16:45:46] Evaluate_04: epoch = 1000 train time = 34 s train loss = 0.009165 train acc = 1.0000, test acc = 0.9387
# Evaluate 5 random ConvNet, mean = 0.9413 std = 0.0021
# -------------------------
# [2022-11-27 16:45:55] iter = 0040, loss = 53.3074
# [2022-11-27 16:47:28] iter = 0050, loss = 49.0489
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 60
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-27 16:49:28] Evaluate_00: epoch = 1000 train time = 33 s train loss = 0.014732 train acc = 1.0000, test acc = 0.9545
# [2022-11-27 16:50:05] Evaluate_01: epoch = 1000 train time = 35 s train loss = 0.008886 train acc = 1.0000, test acc = 0.9591
# [2022-11-27 16:50:41] Evaluate_02: epoch = 1000 train time = 34 s train loss = 0.011649 train acc = 1.0000, test acc = 0.9568
# [2022-11-27 16:51:18] Evaluate_03: epoch = 1000 train time = 34 s train loss = 0.015483 train acc = 1.0000, test acc = 0.9540
# [2022-11-27 16:51:54] Evaluate_04: epoch = 1000 train time = 34 s train loss = 0.007965 train acc = 1.0000, test acc = 0.9568
# Evaluate 5 random ConvNet, mean = 0.9562 std = 0.0018
# -------------------------
# [2022-11-27 16:52:04] iter = 0060, loss = 45.1301
# [2022-11-27 16:53:37] iter = 0070, loss = 44.8659
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 80
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-27 16:55:37] Evaluate_00: epoch = 1000 train time = 34 s train loss = 0.004012 train acc = 1.0000, test acc = 0.9611
# [2022-11-27 16:56:13] Evaluate_01: epoch = 1000 train time = 34 s train loss = 0.009961 train acc = 1.0000, test acc = 0.9611
# [2022-11-27 16:56:49] Evaluate_02: epoch = 1000 train time = 34 s train loss = 0.010348 train acc = 1.0000, test acc = 0.9621
# [2022-11-27 16:57:26] Evaluate_03: epoch = 1000 train time = 34 s train loss = 0.012125 train acc = 1.0000, test acc = 0.9591
# [2022-11-27 16:58:03] Evaluate_04: epoch = 1000 train time = 34 s train loss = 0.009904 train acc = 1.0000, test acc = 0.9596
# Evaluate 5 random ConvNet, mean = 0.9606 std = 0.0011
# -------------------------
# [2022-11-27 16:58:12] iter = 0080, loss = 43.7752
# [2022-11-27 16:59:45] iter = 0090, loss = 42.4326
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 100
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# [2022-11-27 17:01:45] Evaluate_00: epoch = 1000 train time = 34 s train loss = 0.009922 train acc = 1.0000, test acc = 0.9630
# [2022-11-27 17:02:21] Evaluate_01: epoch = 1000 train time = 34 s train loss = 0.009203 train acc = 1.0000, test acc = 0.9629
# [2022-11-27 17:02:57] Evaluate_02: epoch = 1000 train time = 34 s train loss = 0.007909 train acc = 1.0000, test acc = 0.9645
# [2022-11-27 17:03:34] Evaluate_03: epoch = 1000 train time = 34 s train loss = 0.026796 train acc = 1.0000, test acc = 0.9662
# [2022-11-27 17:04:11] Evaluate_04: epoch = 1000 train time = 34 s train loss = 0.008405 train acc = 1.0000, test acc = 0.9646
# Evaluate 5 random ConvNet, mean = 0.9642 std = 0.0012
# -------------------------
# [2022-11-27 17:04:20] iter = 0100, loss = 41.2315
#
# ==================== Final Results ====================
#
# Run 1 experiments, train on ConvNet, evaluate 5 random ConvNet, mean  = 96.42%  std = 0.12%

# %%
# !zip -r /content/result.zip /content/result
from google.colab import files
files.download("/content/result.zip")
# Out:
# updating: content/result/ (stored 0%)
# updating: content/result/vis_DC_MNIST_ConvNet_10ipc_exp0_iter60.png (deflated 5%)
# updating: content/result/vis_DC_MNIST_ConvNet_10ipc_exp0_iter40.png (deflated 4%)
# updating: content/result/res_DC_MNIST_ConvNet_10ipc.pt (deflated 9%)
# updating: content/result/vis_DC_MNIST_ConvNet_10ipc_exp0_iter100.png (deflated 5%)
# updating: content/result/vis_DC_MNIST_ConvNet_10ipc_exp0_iter20.png (deflated 4%)
# updating: content/result/vis_DC_MNIST_ConvNet_10ipc_exp0_iter0.png (deflated 5%)
# updating: content/result/vis_DC_MNIST_ConvNet_10ipc_exp0_iter80.png (deflated 5%)

# %% [markdown]
# ## Load up distilled dataset and train model

# %%
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image
import time

class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'MNIST'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 256
    self.batch_train = 256
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'

args = myArgs()
args.outer_loop, args.inner_loop = get_loops(args.ipc)
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
args.dsa_param = ParamDiffAug()
args.dsa = True if args.method == 'DSA' else False


distilled_set_name = '/content/result/res_DC_MNIST_ConvNet_10ipc.pt'
dataset = torch.load(distilled_set_name)
syn_data = dataset['data']
syn_data = TensorDataset(syn_data[0][0], syn_data[0][1])

channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)
net = get_network(args.model, channel, num_classes, im_size).to(args.device)


net.train()
optimizer_net = torch.optim.SGD(net.parameters(), lr=0.01)  # optimizer_img for synthetic data
optimizer_net.zero_grad()

criterion = nn.CrossEntropyLoss().to(args.device)

num_epochs = 20

trainloader = torch.utils.data.DataLoader(syn_data, batch_size=1, shuffle=True, num_workers=0)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_net, num_epochs)


start = time.time()

for i in range(num_epochs):
  loss_avg, acc_avg = epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
  for param_group in optimizer_net.param_groups:
    print("Current learning rate is: {}".format(param_group['lr']))

  print("Epoch[{}/{}]: Loss: {:.4f}, ACC: {:.4f}".format(i+1,num_epochs, loss_avg, acc_avg))
  scheduler.step()

print(time.time() - start)

testloader = torch.utils.data.DataLoader(dst_test, batch_size=args.batch_train, shuffle=True, num_workers=0)
net.eval()
loss_avg, acc_avg = epoch('test', testloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)

print("Test set: Loss: {:.4f}, ACC: {:.4f}".format(loss_avg, acc_avg))
# Out:
# Current learning rate is: 0.01
# Epoch[1/20]: Loss: 3.5412, ACC: 0.0400
# Current learning rate is: 0.009938441702975689
# Epoch[2/20]: Loss: 1.6428, ACC: 0.3900
# Current learning rate is: 0.009755282581475769
# Epoch[3/20]: Loss: 1.0073, ACC: 0.6000
# Current learning rate is: 0.00945503262094184
# Epoch[4/20]: Loss: 0.4715, ACC: 0.8600
# Current learning rate is: 0.009045084971874739
# Epoch[5/20]: Loss: 0.2918, ACC: 0.9700
# Current learning rate is: 0.008535533905932738
# Epoch[6/20]: Loss: 0.0921, ACC: 1.0000
# Current learning rate is: 0.007938926261462366
# Epoch[7/20]: Loss: 0.0562, ACC: 1.0000
# Current learning rate is: 0.007269952498697735
# Epoch[8/20]: Loss: 0.0385, ACC: 1.0000
# Current learning rate is: 0.006545084971874738
# Epoch[9/20]: Loss: 0.0303, ACC: 1.0000
# Current learning rate is: 0.005782172325201155
# Epoch[10/20]: Loss: 0.0263, ACC: 1.0000
# Current learning rate is: 0.005
# Epoch[11/20]: Loss: 0.0230, ACC: 1.0000
# Current learning rate is: 0.004217827674798847
# Epoch[12/20]: Loss: 0.0211, ACC: 1.0000
# Current learning rate is: 0.0034549150281252636
# Epoch[13/20]: Loss: 0.0196, ACC: 1.0000
# Current learning rate is: 0.0027300475013022664
# Epoch[14/20]: Loss: 0.0186, ACC: 1.0000
# Current learning rate is: 0.0020610737385376348
# Epoch[15/20]: Loss: 0.0177, ACC: 1.0000
# Current learning rate is: 0.0014644660940672626
# Epoch[16/20]: Loss: 0.0172, ACC: 1.0000
# Current learning rate is: 0.0009549150281252633
# Epoch[17/20]: Loss: 0.0168, ACC: 1.0000
# Current learning rate is: 0.0005449673790581611
# Epoch[18/20]: Loss: 0.0165, ACC: 1.0000
# Current learning rate is: 0.00024471741852423234
# Epoch[19/20]: Loss: 0.0164, ACC: 1.0000
# Current learning rate is: 6.15582970243117e-05
# Epoch[20/20]: Loss: 0.0163, ACC: 1.0000
# 5.2635180950164795
# Test set: Loss: 0.1901, ACC: 0.9401

# %% [markdown]
# ## Test trajectory matching results

# %%
# !pip install kornia
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kornia in /usr/local/lib/python3.7/dist-packages (0.6.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from kornia) (21.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from kornia) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.8.1->kornia) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->kornia) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.5-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 36.4 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 68.9 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.19.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 74.0 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.0-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 72.7 MB/s
#   Downloading sentry_sdk-1.10.1-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 72.2 MB/s
#   Downloading sentry_sdk-1.10.0-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 69.6 MB/s
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 68.2 MB/s
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 76.5 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 79.8 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 80.1 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 68.4 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 78.4 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 79.6 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 71.2 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 80.4 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 80.2 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 67.3 MB/s
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=b37ec01d769e43f2836eff42728c0ad40c127087707ab367d32a0e3e06acf359
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.29 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 wandb-0.13.5

# %%
# !python distill.py --dataset=CIFAR10 --model=ConvNet --ipc=10 --syn_steps=30 --expert_epochs=2 --max_start_epoch=15 --Iteration=1000 --num_eval=2
# Out:
# CUDNN STATUS: True
# Files already downloaded and verified
# Files already downloaded and verified
# wandb: Currently logged in as: fredshi1997. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/wandb/run-20221129_205400-3axihmoj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run clear-river-13
# wandb: ⭐️ View project at https://wandb.ai/fredshi1997/dip
# wandb: 🚀 View run at https://wandb.ai/fredshi1997/dip/runs/3axihmoj
# Hyper-parameters:
#  {'dataset': 'CIFAR10', 'subset': 'imagenette', 'model': 'ConvNet', 'ipc': 10, 'eval_mode': 'S', 'num_eval': 2, 'eval_it': 100, 'epoch_eval_train': 1000, 'Iteration': 1000, 'lr_img': 1000, 'lr_lr': 1e-05, 'lr_teacher': 0.01, 'lr_init': 0.01, 'batch_real': 256, 'batch_syn': 100, 'batch_train': 256, 'pix_init': 'real', 'dsa': True, 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': 'data', 'buffer_path': './buffers', 'expert_epochs': 2, 'syn_steps': 30, 'max_start_epoch': 15, 'zca': False, 'load_all': False, 'no_aug': False, 'texture': False, 'canvas_size': 2, 'canvas_samples': 1, 'max_files': None, 'max_experts': None, 'force_save': False, 'device': 'cuda', 'im_size': [32, 32], 'dc_aug_param': None, 'dsa_param': <utils.ParamDiffAug object at 0x7fc046e8eb50>, '_wandb': {}, 'zca_trans': None, 'distributed': False}
# Evaluation model pool:  ['ConvNet']
# BUILDING DATASET
# 100% 50000/50000 [00:10<00:00, 4684.84it/s]
# 50000it [00:00, 2858440.44it/s]
# class c = 0: 5000 real images
# class c = 1: 5000 real images
# class c = 2: 5000 real images
# class c = 3: 5000 real images
# class c = 4: 5000 real images
# class c = 5: 5000 real images
# class c = 6: 5000 real images
# class c = 7: 5000 real images
# class c = 8: 5000 real images
# class c = 9: 5000 real images
# real images channel 0, mean = -0.0000, std = 1.2211
# real images channel 1, mean = -0.0002, std = 1.2211
# real images channel 2, mean = 0.0002, std = 1.3014
# distill.py:111: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   label_syn = torch.tensor([np.ones(args.ipc,dtype=np.int_)*i for i in range(num_classes)], dtype=torch.long, requires_grad=False, device=args.device).view(-1) # [0,0,0, 1,1,1, ..., 9,9,9]
# initialize synthetic data from random real images
# [2022-11-29 20:54:14] training begins
# Expert Dir: ./buffers/CIFAR10_NO_ZCA/ConvNet
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 0
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5}
#   0% 0/1001 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100% 1001/1001 [00:15<00:00, 63.37it/s]
# [2022-11-29 20:54:30] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000499 train acc = 1.0000, test acc = 0.3128
# 100% 1001/1001 [00:14<00:00, 69.11it/s]
# [2022-11-29 20:54:44] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.000563 train acc = 1.0000, test acc = 0.3189
# Evaluate 2 random ConvNet, mean = 0.3159 std = 0.0030
# -------------------------
# [2022-11-29 20:54:47] iter = 0000, loss = 1.2514
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:55:03] iter = 0010, loss = 0.9723
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:55:19] iter = 0020, loss = 0.9714
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:55:36] iter = 0030, loss = 0.9286
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:55:52] iter = 0040, loss = 0.9571
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 20:56:08] iter = 0050, loss = 0.8383
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:56:25] iter = 0060, loss = 0.8212
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 20:56:41] iter = 0070, loss = 0.9191
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:56:57] iter = 0080, loss = 0.9007
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 20:57:14] iter = 0090, loss = 0.9430
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 100
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 68.33it/s]
# [2022-11-29 20:57:43] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.007556 train acc = 1.0000, test acc = 0.4957
# 100% 1001/1001 [00:15<00:00, 64.82it/s]
# [2022-11-29 20:57:59] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.001460 train acc = 1.0000, test acc = 0.5118
# Evaluate 2 random ConvNet, mean = 0.5038 std = 0.0081
# -------------------------
# [2022-11-29 20:58:01] iter = 0100, loss = 0.8924
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:58:17] iter = 0110, loss = 0.9530
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 20:58:34] iter = 0120, loss = 0.9477
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 20:58:50] iter = 0130, loss = 0.7431
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:59:07] iter = 0140, loss = 0.9397
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 20:59:23] iter = 0150, loss = 0.8668
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 20:59:40] iter = 0160, loss = 0.8867
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 20:59:57] iter = 0170, loss = 0.9138
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:00:13] iter = 0180, loss = 0.6635
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:00:30] iter = 0190, loss = 0.9184
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 200
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 63.26it/s]
# [2022-11-29 21:01:00] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.006986 train acc = 1.0000, test acc = 0.5303
# 100% 1001/1001 [00:15<00:00, 66.01it/s]
# [2022-11-29 21:01:15] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.002777 train acc = 1.0000, test acc = 0.5410
# Evaluate 2 random ConvNet, mean = 0.5356 std = 0.0054
# -------------------------
# [2022-11-29 21:01:18] iter = 0200, loss = 0.8062
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:01:34] iter = 0210, loss = 0.6423
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:01:51] iter = 0220, loss = 0.6144
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:02:07] iter = 0230, loss = 0.9428
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:02:24] iter = 0240, loss = 0.6227
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:02:40] iter = 0250, loss = 0.9187
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:02:57] iter = 0260, loss = 0.9462
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:03:13] iter = 0270, loss = 0.6162
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:03:30] iter = 0280, loss = 0.6213
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:03:46] iter = 0290, loss = 0.6809
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 300
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 67.34it/s]
# [2022-11-29 21:04:16] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.006003 train acc = 1.0000, test acc = 0.5375
# 100% 1001/1001 [00:14<00:00, 67.61it/s]
# [2022-11-29 21:04:31] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.002414 train acc = 1.0000, test acc = 0.5533
# Evaluate 2 random ConvNet, mean = 0.5454 std = 0.0079
# -------------------------
# [2022-11-29 21:04:33] iter = 0300, loss = 0.6115
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:04:49] iter = 0310, loss = 0.9294
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:05:06] iter = 0320, loss = 0.7944
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:05:22] iter = 0330, loss = 0.8370
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:05:39] iter = 0340, loss = 0.7846
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:05:55] iter = 0350, loss = 0.8106
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:06:12] iter = 0360, loss = 0.8160
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:06:28] iter = 0370, loss = 0.8661
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:06:45] iter = 0380, loss = 0.5364
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:07:01] iter = 0390, loss = 0.8495
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 400
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 68.20it/s]
# [2022-11-29 21:07:31] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.000143 train acc = 1.0000, test acc = 0.5629
# 100% 1001/1001 [00:14<00:00, 68.00it/s]
# [2022-11-29 21:07:46] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.000149 train acc = 1.0000, test acc = 0.5658
# Evaluate 2 random ConvNet, mean = 0.5643 std = 0.0015
# -------------------------
# [2022-11-29 21:07:48] iter = 0400, loss = 0.7626
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:08:04] iter = 0410, loss = 0.5983
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:08:21] iter = 0420, loss = 0.9265
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:08:37] iter = 0430, loss = 0.7041
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:08:54] iter = 0440, loss = 0.9244
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:09:10] iter = 0450, loss = 0.5670
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:09:26] iter = 0460, loss = 0.7064
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:09:43] iter = 0470, loss = 0.9202
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:09:59] iter = 0480, loss = 0.7002
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:10:16] iter = 0490, loss = 0.7347
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 500
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 67.97it/s]
# [2022-11-29 21:10:45] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.003437 train acc = 1.0000, test acc = 0.5680
# 100% 1001/1001 [00:14<00:00, 67.98it/s]
# [2022-11-29 21:11:00] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.001294 train acc = 1.0000, test acc = 0.5729
# Evaluate 2 random ConvNet, mean = 0.5704 std = 0.0025
# -------------------------
# [2022-11-29 21:11:02] iter = 0500, loss = 0.9404
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:11:19] iter = 0510, loss = 0.9294
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:11:35] iter = 0520, loss = 0.8988
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:11:52] iter = 0530, loss = 0.7132
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:12:08] iter = 0540, loss = 0.9188
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:12:25] iter = 0550, loss = 0.9299
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:12:41] iter = 0560, loss = 0.8341
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:12:58] iter = 0570, loss = 0.5198
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:13:14] iter = 0580, loss = 0.9136
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:13:30] iter = 0590, loss = 0.9076
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 600
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 67.70it/s]
# [2022-11-29 21:14:00] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.000189 train acc = 1.0000, test acc = 0.5712
# 100% 1001/1001 [00:14<00:00, 67.26it/s]
# [2022-11-29 21:14:15] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.004225 train acc = 1.0000, test acc = 0.5658
# Evaluate 2 random ConvNet, mean = 0.5685 std = 0.0027
# -------------------------
# [2022-11-29 21:14:17] iter = 0600, loss = 0.7700
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:14:33] iter = 0610, loss = 0.8146
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:14:50] iter = 0620, loss = 0.5980
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:15:06] iter = 0630, loss = 0.5922
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:15:23] iter = 0640, loss = 0.8524
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:15:39] iter = 0650, loss = 0.6228
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:15:56] iter = 0660, loss = 0.8752
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:16:12] iter = 0670, loss = 0.8178
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:16:29] iter = 0680, loss = 0.8905
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:16:45] iter = 0690, loss = 0.8791
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 700
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 66.92it/s]
# [2022-11-29 21:17:15] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.000227 train acc = 1.0000, test acc = 0.5715
# 100% 1001/1001 [00:14<00:00, 67.51it/s]
# [2022-11-29 21:17:30] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.000172 train acc = 1.0000, test acc = 0.5812
# Evaluate 2 random ConvNet, mean = 0.5764 std = 0.0049
# -------------------------
# [2022-11-29 21:17:32] iter = 0700, loss = 0.6209
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:17:48] iter = 0710, loss = 0.6483
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:18:05] iter = 0720, loss = 0.6821
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:18:21] iter = 0730, loss = 0.5567
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:18:38] iter = 0740, loss = 0.9410
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:18:54] iter = 0750, loss = 0.7828
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:19:11] iter = 0760, loss = 0.5766
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:19:27] iter = 0770, loss = 0.6651
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:19:44] iter = 0780, loss = 0.5309
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:20:00] iter = 0790, loss = 0.8992
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 800
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 67.89it/s]
# [2022-11-29 21:20:30] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.000207 train acc = 1.0000, test acc = 0.5744
# 100% 1001/1001 [00:14<00:00, 67.75it/s]
# [2022-11-29 21:20:45] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.000583 train acc = 1.0000, test acc = 0.5752
# Evaluate 2 random ConvNet, mean = 0.5748 std = 0.0004
# -------------------------
# [2022-11-29 21:20:47] iter = 0800, loss = 0.9159
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:21:03] iter = 0810, loss = 0.6123
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:21:20] iter = 0820, loss = 0.4961
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:21:36] iter = 0830, loss = 0.9233
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:21:53] iter = 0840, loss = 0.6919
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:22:09] iter = 0850, loss = 0.9251
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:22:26] iter = 0860, loss = 0.7933
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:22:42] iter = 0870, loss = 0.9215
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:22:58] iter = 0880, loss = 0.6008
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:23:15] iter = 0890, loss = 0.6181
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 900
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 64.25it/s]
# [2022-11-29 21:23:45] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.001560 train acc = 1.0000, test acc = 0.5862
# 100% 1001/1001 [00:15<00:00, 64.40it/s]
# [2022-11-29 21:24:01] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000112 train acc = 1.0000, test acc = 0.5975
# Evaluate 2 random ConvNet, mean = 0.5918 std = 0.0056
# -------------------------
# [2022-11-29 21:24:03] iter = 0900, loss = 0.9236
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:24:19] iter = 0910, loss = 0.6065
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:24:36] iter = 0920, loss = 0.9271
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:24:52] iter = 0930, loss = 0.5110
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:25:09] iter = 0940, loss = 0.8550
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:25:25] iter = 0950, loss = 0.8525
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:25:42] iter = 0960, loss = 0.8508
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:25:58] iter = 0970, loss = 0.7120
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-11-29 21:26:15] iter = 0980, loss = 0.5727
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-11-29 21:26:31] iter = 0990, loss = 0.7956
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 1000
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:14<00:00, 67.99it/s]
# [2022-11-29 21:27:01] Evaluate_00: epoch = 1000 train time = 14 s train loss = 0.000544 train acc = 1.0000, test acc = 0.5772
# 100% 1001/1001 [00:14<00:00, 68.03it/s]
# [2022-11-29 21:27:16] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.000101 train acc = 1.0000, test acc = 0.5703
# Evaluate 2 random ConvNet, mean = 0.5737 std = 0.0035
# -------------------------
# [2022-11-29 21:27:18] iter = 1000, loss = 0.9142
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:     Accuracy/ConvNet ▁▆▇▇▇▇▇████
# wandb:           Grand_Loss ▇██▆▇▅▇▇▄▃█▇▃▂▆▇▇▄▅▃▇▅▇▇▃▂▅▂▇▂▇▃▃▂▇▁▂▇▂▂
# wandb: Max_Accuracy/ConvNet ▁▆▇▇▇▇▇████
# wandb:      Max_Std/ConvNet ▃█▅█▁▂▂▅▅▅▅
# wandb:             Progress ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          Start_Epoch ▃▇▇▄▅▃▅▅▃▁▇▇▃▁▅▇▅▃▄▃▇▅▇█▃▃▅▁▆▂▆▁▁▃▇▁▂▇▃▃
# wandb:          Std/ConvNet ▃█▆█▂▃▃▅▁▆▄
# wandb:         Synthetic_LR ▁▁▂▂▃▃▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇███████████
# wandb:
# wandb: Run summary:
# wandb:     Accuracy/ConvNet 0.57375
# wandb:           Grand_Loss 0.9142
# wandb: Max_Accuracy/ConvNet 0.59185
# wandb:      Max_Std/ConvNet 0.00565
# wandb:             Progress 1000
# wandb:          Start_Epoch 14
# wandb:          Std/ConvNet 0.00345
# wandb:         Synthetic_LR 0.02546
# wandb:
# wandb: Synced clear-river-13: https://wandb.ai/fredshi1997/dip/runs/3axihmoj
# wandb: Synced 5 W&B file(s), 22 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20221129_205400-3axihmoj/logs

# %%
# !zip -r /content/logged_files.zip /content/logged_files
from google.colab import files
files.download("/content/logged_files.zip")
# Out:
#   adding: content/logged_files/ (stored 0%)
#   adding: content/logged_files/CIFAR10/ (stored 0%)
#   adding: content/logged_files/CIFAR10/.ipynb_checkpoints/ (stored 0%)
#   adding: content/logged_files/CIFAR10/clear-river-13/ (stored 0%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_1000.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_0.pt (deflated 65%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_best.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_500.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_1000.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_900.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_500.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_700.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_600.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_200.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_800.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_900.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_200.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_300.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_best.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_400.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_400.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_700.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_100.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_600.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_800.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_300.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_100.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_0.pt (deflated 76%)

# %%
# !unzip logged_files.zip
# Out:
# Archive:  /content/logged_files.zip
#    creating: content/logged_files/
#    creating: content/logged_files/CIFAR10/
#    creating: content/logged_files/CIFAR10/atomic-field-23/
#   inflating: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter100.png
#   inflating: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter300.png
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_200.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_600.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter1000.png
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_300.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_500.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_200.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_1000.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter200.png
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_best.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_best.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter0.png
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_100.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter600.png
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_500.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_0.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_600.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_0.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter500.png
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_1000.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/labels_300.pt
#   inflating: content/logged_files/CIFAR10/atomic-field-23/images_100.pt
#    creating: content/logged_files/CIFAR10/.ipynb_checkpoints/
#    creating: content/logged_files/CIFAR10/clear-river-13/
#   inflating: content/logged_files/CIFAR10/clear-river-13/labels_900.pt
#   inflating: content/logged_files/CIFAR10/clear-river-13/images_0.pt
#   inflating: content/logged_files/CIFAR10/clear-river-13/labels_0.pt
#   inflating: content/logged_files/CIFAR10/clear-river-13/images_900.pt
#    creating: content/logged_files/CIFAR10/efficient-waterfall-22/
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_700.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter700.png
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter100.png
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_200.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_600.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter1000.png
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_700.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_200.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_1000.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter200.png
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_best.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_400.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_best.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter0.png
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_100.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter600.png
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_400.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_0.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_600.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_0.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/labels_1000.pt
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter400.png
#   inflating: content/logged_files/CIFAR10/efficient-waterfall-22/images_100.pt
#    creating: content/logged_files/.ipynb_checkpoints/

# %% [markdown]
# Train from trajectory matching initialized from real

# %%
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image

class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'CIFAR10'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 256
    self.batch_train = 256
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'

args = myArgs()
args.outer_loop, args.inner_loop = get_loops(args.ipc)
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
args.dsa_param = ParamDiffAug()
args.dsa = True if args.method == 'DSA' else False


distilled_set_name = '/content/logged_files/CIFAR10/clear-river-13/images_900.pt'
distilled_label_name = '/content/logged_files/CIFAR10/clear-river-13/labels_900.pt'
data = torch.load(distilled_set_name)
label = torch.load(distilled_label_name)

print(len(label))


syn_data = TensorDataset(data, label)


channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)
net = get_network(args.model, channel, num_classes, im_size).to(args.device)


net.train()
optimizer_net = torch.optim.SGD(net.parameters(), lr=0.01)  # optimizer_img for synthetic data
optimizer_net.zero_grad()

criterion = nn.CrossEntropyLoss().to(args.device)

num_epochs = 20

trainloader = torch.utils.data.DataLoader(syn_data, batch_size=1, shuffle=True, num_workers=0)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_net, num_epochs)


for i in range(num_epochs):
  loss_avg, acc_avg = epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
  for param_group in optimizer_net.param_groups:
    print("Current learning rate is: {}".format(param_group['lr']))

  print("Epoch[{}/{}]: Loss: {:.4f}, ACC: {:.4f}".format(i+1,num_epochs, loss_avg, acc_avg))
  scheduler.step()


testloader = torch.utils.data.DataLoader(dst_test, batch_size=args.batch_train, shuffle=True, num_workers=0)
net.eval()
loss_avg, acc_avg = epoch('test', testloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)

print("Test set: Loss: {:.4f}, ACC: {:.4f}".format(loss_avg, acc_avg))
# Out:
# 100
# Files already downloaded and verified
# Files already downloaded and verified
# Current learning rate is: 0.01
# Epoch[1/20]: Loss: 4.4712, ACC: 0.1100
# Current learning rate is: 0.009938441702975689
# Epoch[2/20]: Loss: 3.7992, ACC: 0.1400
# Current learning rate is: 0.009755282581475769
# Epoch[3/20]: Loss: 2.6815, ACC: 0.1700
# Current learning rate is: 0.00945503262094184
# Epoch[4/20]: Loss: 1.8079, ACC: 0.3900
# Current learning rate is: 0.009045084971874739
# Epoch[5/20]: Loss: 0.9629, ACC: 0.6500
# Current learning rate is: 0.008535533905932738
# Epoch[6/20]: Loss: 0.2185, ACC: 0.9900
# Current learning rate is: 0.007938926261462366
# Epoch[7/20]: Loss: 0.0614, ACC: 1.0000
# Current learning rate is: 0.007269952498697735
# Epoch[8/20]: Loss: 0.0388, ACC: 1.0000
# Current learning rate is: 0.006545084971874738
# Epoch[9/20]: Loss: 0.0308, ACC: 1.0000
# Current learning rate is: 0.005782172325201155
# Epoch[10/20]: Loss: 0.0261, ACC: 1.0000
# Current learning rate is: 0.005
# Epoch[11/20]: Loss: 0.0231, ACC: 1.0000
# Current learning rate is: 0.004217827674798847
# Epoch[12/20]: Loss: 0.0211, ACC: 1.0000
# Current learning rate is: 0.0034549150281252636
# Epoch[13/20]: Loss: 0.0196, ACC: 1.0000
# Current learning rate is: 0.0027300475013022664
# Epoch[14/20]: Loss: 0.0185, ACC: 1.0000
# Current learning rate is: 0.0020610737385376348
# Epoch[15/20]: Loss: 0.0177, ACC: 1.0000
# Current learning rate is: 0.0014644660940672626
# Epoch[16/20]: Loss: 0.0172, ACC: 1.0000
# Current learning rate is: 0.0009549150281252633
# Epoch[17/20]: Loss: 0.0168, ACC: 1.0000
# Current learning rate is: 0.0005449673790581611
# Epoch[18/20]: Loss: 0.0165, ACC: 1.0000
# Current learning rate is: 0.00024471741852423234
# Epoch[19/20]: Loss: 0.0164, ACC: 1.0000
# Current learning rate is: 6.15582970243117e-05
# Epoch[20/20]: Loss: 0.0163, ACC: 1.0000
# Test set: Loss: 1.5873, ACC: 0.4575

# %% [markdown]
# Train from trajectory matching initialized from noise

# %%
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image

class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'CIFAR10'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 256
    self.batch_train = 256
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'

args = myArgs()
args.outer_loop, args.inner_loop = get_loops(args.ipc)
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
args.dsa_param = ParamDiffAug()
args.dsa = True if args.method == 'DSA' else False


distilled_set_name = '/content/logged_files/CIFAR10/efficient-waterfall-22/images_best.pt'
distilled_label_name = '/content/logged_files/CIFAR10/efficient-waterfall-22/labels_best.pt'
data = torch.load(distilled_set_name)
label = torch.load(distilled_label_name)

print(len(label))


syn_data = TensorDataset(data, label)


channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)
net = get_network(args.model, channel, num_classes, im_size).to(args.device)


net.train()
optimizer_net = torch.optim.SGD(net.parameters(), lr=0.01)  # optimizer_img for synthetic data
optimizer_net.zero_grad()

criterion = nn.CrossEntropyLoss().to(args.device)

num_epochs = 20

trainloader = torch.utils.data.DataLoader(syn_data, batch_size=1, shuffle=True, num_workers=0)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_net, num_epochs)


for i in range(num_epochs):
  loss_avg, acc_avg = epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
  for param_group in optimizer_net.param_groups:
    print("Current learning rate is: {}".format(param_group['lr']))

  print("Epoch[{}/{}]: Loss: {:.4f}, ACC: {:.4f}".format(i+1,num_epochs, loss_avg, acc_avg))
  scheduler.step()


testloader = torch.utils.data.DataLoader(dst_test, batch_size=args.batch_train, shuffle=True, num_workers=0)
net.eval()
loss_avg, acc_avg = epoch('test', testloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)

print("Test set: Loss: {:.4f}, ACC: {:.4f}".format(loss_avg, acc_avg))
# Out:
# 100
# Files already downloaded and verified
# Files already downloaded and verified
# Current learning rate is: 0.01
# Epoch[1/20]: Loss: 4.1695, ACC: 0.1300
# Current learning rate is: 0.009938441702975689
# Epoch[2/20]: Loss: 3.0258, ACC: 0.1400
# Current learning rate is: 0.009755282581475769
# Epoch[3/20]: Loss: 1.8360, ACC: 0.3700
# Current learning rate is: 0.00945503262094184
# Epoch[4/20]: Loss: 0.7931, ACC: 0.7600
# Current learning rate is: 0.009045084971874739
# Epoch[5/20]: Loss: 0.1531, ACC: 0.9900
# Current learning rate is: 0.008535533905932738
# Epoch[6/20]: Loss: 0.0424, ACC: 1.0000
# Current learning rate is: 0.007938926261462366
# Epoch[7/20]: Loss: 0.0260, ACC: 1.0000
# Current learning rate is: 0.007269952498697735
# Epoch[8/20]: Loss: 0.0213, ACC: 1.0000
# Current learning rate is: 0.006545084971874738
# Epoch[9/20]: Loss: 0.0186, ACC: 1.0000
# Current learning rate is: 0.005782172325201155
# Epoch[10/20]: Loss: 0.0166, ACC: 1.0000
# Current learning rate is: 0.005
# Epoch[11/20]: Loss: 0.0152, ACC: 1.0000
# Current learning rate is: 0.004217827674798847
# Epoch[12/20]: Loss: 0.0142, ACC: 1.0000
# Current learning rate is: 0.0034549150281252636
# Epoch[13/20]: Loss: 0.0135, ACC: 1.0000
# Current learning rate is: 0.0027300475013022664
# Epoch[14/20]: Loss: 0.0129, ACC: 1.0000
# Current learning rate is: 0.0020610737385376348
# Epoch[15/20]: Loss: 0.0125, ACC: 1.0000
# Current learning rate is: 0.0014644660940672626
# Epoch[16/20]: Loss: 0.0122, ACC: 1.0000
# Current learning rate is: 0.0009549150281252633
# Epoch[17/20]: Loss: 0.0120, ACC: 1.0000
# Current learning rate is: 0.0005449673790581611
# Epoch[18/20]: Loss: 0.0118, ACC: 1.0000
# Current learning rate is: 0.00024471741852423234
# Epoch[19/20]: Loss: 0.0118, ACC: 1.0000
# Current learning rate is: 6.15582970243117e-05
# Epoch[20/20]: Loss: 0.0117, ACC: 1.0000
# Test set: Loss: 1.9450, ACC: 0.3597

# %%
# !pip install flopth
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flopth in /usr/local/lib/python3.8/dist-packages (0.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from flopth) (0.13.1+cu113)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from flopth) (0.8.10)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from flopth) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from flopth) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->flopth) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision->flopth) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->flopth) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->flopth) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->flopth) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->flopth) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->flopth) (3.0.4)

# %%
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image

class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'MNIST'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 256
    self.batch_train = 256
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'

args = myArgs()
args.outer_loop, args.inner_loop = get_loops(args.ipc)
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
args.dsa_param = ParamDiffAug()
args.dsa = True if args.method == 'DSA' else False


channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)

net = get_network(args.model, channel, num_classes, im_size).to(args.device)

# %%
print(im_size)
print(len(dst_train))

from flopth import flopth
flops, params = flopth(net, in_size=((1, 28, 28),), bare_number=False)
print("1 image FLOPS is {0}".format(flops))
num = len(dst_train)
flops, params = flopth(net, in_size=((1, 28, 28),), show_detail=True, bare_number=True)
flops_original = flops * num / (1000 * 1000 * 1000)
flops_distilled = 100 * num / (1000 * 1000 * 1000)
print("Train entire training set of {0} images, FLOPS is {1} G".format(num, flops_original))
print("Train distilled training set of 100 images, FLOPS is {0} G".format(flops_distilled))
#
# Out:
# (28, 28)
# 60000
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# 1 image FLOPS is 48.9021M
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# Op GroupNorm is not supported at now.
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | module_name   | module_type   | in_shape    | out_shape   | params   | params_percent   | params_percent_vis      | flops    | flops_percent   | flops_percent_vis                      |
# +===============+===============+=============+=============+==========+==================+=========================+==========+=================+========================================+
# | features.0    | Conv2d        | (1,28,28)   | (128,32,32) | 1.28K    | 0.402888%        |                         | 1.31072M | 2.68029%        | #                                      |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.1    | GroupNorm     | (128,32,32) | (128,32,32) | 256.0    | 0.0805776%       |                         | 0.0      | 0.0%            |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.2    | ReLU          | (128,32,32) | (128,32,32) | 0.0      | 0.0%             |                         | 131.072K | 0.268029%       |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.3    | AvgPool2d     | (128,32,32) | (128,16,16) | 0.0      | 0.0%             |                         | 131.072K | 0.268029%       |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.4    | Conv2d        | (128,16,16) | (128,16,16) | 147.584K | 46.453%          | ####################### | 37.7815M | 77.2594%        | ###################################### |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.5    | GroupNorm     | (128,16,16) | (128,16,16) | 256.0    | 0.0805776%       |                         | 0.0      | 0.0%            |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.6    | ReLU          | (128,16,16) | (128,16,16) | 0.0      | 0.0%             |                         | 32.768K  | 0.0670073%      |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.7    | AvgPool2d     | (128,16,16) | (128,8,8)   | 0.0      | 0.0%             |                         | 32.768K  | 0.0670073%      |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.8    | Conv2d        | (128,8,8)   | (128,8,8)   | 147.584K | 46.453%          | ####################### | 9.44538M | 19.3149%        | #########                              |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.9    | GroupNorm     | (128,8,8)   | (128,8,8)   | 256.0    | 0.0805776%       |                         | 0.0      | 0.0%            |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.10   | ReLU          | (128,8,8)   | (128,8,8)   | 0.0      | 0.0%             |                         | 8.192K   | 0.0167518%      |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | features.11   | AvgPool2d     | (128,8,8)   | (128,4,4)   | 0.0      | 0.0%             |                         | 8.192K   | 0.0167518%      |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
# | classifier    | Linear        | (2048)      | (10)        | 20.49K   | 6.44936%         | ###                     | 20.48K   | 0.0418796%      |                                        |
# +---------------+---------------+-------------+-------------+----------+------------------+-------------------------+----------+-----------------+----------------------------------------+
#
#
# Train entire training set of 60000 images, FLOPS is 2934.12864 G
# Train distilled training set of 100 images, FLOPS is 0.006 G

# %% [markdown]
# ## application for distilled dataset - Neural architecture research

# %%
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image

class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'MNIST'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 256
    self.batch_train = 256
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'

args = myArgs()
args.outer_loop, args.inner_loop = get_loops(args.ipc)
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
args.dsa_param = ParamDiffAug()
args.dsa = True if args.method == 'DSA' else False


distilled_set_name = '/content/result/res_DC_MNIST_ConvNet_10ipc.pt'
dataset = torch.load(distilled_set_name)
syn_data = dataset['data']
syn_data = TensorDataset(syn_data[0][0], syn_data[0][1])

channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)

model_list = ['ConvNetD1','ConvNetD2', 'ConvNetD4']
train_list = ['Distilled', 'Original']
accuracy_list = []

for model in model_list:
  for train in train_list:
    run_acc_avg = 0.0
    for i in range(3):
      print(f"Dataset: {train}, model: {model}, run: {i}")
      net = get_network(model, channel, num_classes, im_size).to(args.device)
      net.train()
      optimizer_net = torch.optim.SGD(net.parameters(), lr=0.01)  # optimizer_img for synthetic data
      optimizer_net.zero_grad()

      criterion = nn.CrossEntropyLoss().to(args.device)

      num_epochs = 20

      if train == 'Distilled':
        trainloader = torch.utils.data.DataLoader(syn_data, batch_size=1, shuffle=True, num_workers=0)
      else:
        trainloader = torch.utils.data.DataLoader(dst_train, batch_size=args.batch_train, shuffle=True, num_workers=0)

      scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_net, num_epochs)


      for i in range(num_epochs):
        loss_avg, acc_avg = epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
        # for param_group in optimizer_net.param_groups:
        #   print("Current learning rate is: {}".format(param_group['lr']))

        # print("Epoch[{}/{}]: Loss: {:.4f}, ACC: {:.4f}".format(i+1,num_epochs, loss_avg, acc_avg))
        scheduler.step()


      testloader = torch.utils.data.DataLoader(dst_test, batch_size=args.batch_train, shuffle=True, num_workers=0)
      net.eval()
      loss_avg, acc_avg = epoch('test', testloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
      print("Test set: Loss: {:.4f}, ACC: {:.4f}".format(loss_avg, acc_avg))
      run_acc_avg += acc_avg
    run_acc_avg /= 3.0
    print(f"average test accuracy over 3 runs is: {run_acc_avg}")
    accuracy_list.append(run_acc_avg)


print(accuracy_list)
# Out:
# Dataset: Distilled, model: ConvNetD1, run: 0
# Test set: Loss: 0.5919, ACC: 0.8431
# Dataset: Distilled, model: ConvNetD1, run: 1
# Test set: Loss: 0.5685, ACC: 0.8296
# Dataset: Distilled, model: ConvNetD1, run: 2
# Test set: Loss: 0.5389, ACC: 0.8415
# average test accuracy over 3 runs is: 0.8380666666666666
# Dataset: Original, model: ConvNetD1, run: 0
# Test set: Loss: 0.0657, ACC: 0.9808
# Dataset: Original, model: ConvNetD1, run: 1
# Test set: Loss: 0.0630, ACC: 0.9815
# Dataset: Original, model: ConvNetD1, run: 2
# Test set: Loss: 0.0640, ACC: 0.9810
# average test accuracy over 3 runs is: 0.9811
# Dataset: Distilled, model: ConvNetD2, run: 0
# Test set: Loss: 0.3254, ACC: 0.9112
# Dataset: Distilled, model: ConvNetD2, run: 1
# Test set: Loss: 0.2925, ACC: 0.9163
# Dataset: Distilled, model: ConvNetD2, run: 2
# Test set: Loss: 0.3301, ACC: 0.9107
# average test accuracy over 3 runs is: 0.9127333333333333
# Dataset: Original, model: ConvNetD2, run: 0
# Test set: Loss: 0.0407, ACC: 0.9875
# Dataset: Original, model: ConvNetD2, run: 1
# Test set: Loss: 0.0400, ACC: 0.9885
# Dataset: Original, model: ConvNetD2, run: 2
# Test set: Loss: 0.0401, ACC: 0.9879
# average test accuracy over 3 runs is: 0.9879666666666665
# Dataset: Distilled, model: ConvNetD4, run: 0
# Test set: Loss: 0.2020, ACC: 0.9462
# Dataset: Distilled, model: ConvNetD4, run: 1
# Test set: Loss: 0.2006, ACC: 0.9471
# Dataset: Distilled, model: ConvNetD4, run: 2
# Test set: Loss: 0.2064, ACC: 0.9468
# average test accuracy over 3 runs is: 0.9467
# Dataset: Original, model: ConvNetD4, run: 0
# Test set: Loss: 0.0307, ACC: 0.9926
# Dataset: Original, model: ConvNetD4, run: 1
# Test set: Loss: 0.0300, ACC: 0.9930
# Dataset: Original, model: ConvNetD4, run: 2
# Test set: Loss: 0.0311, ACC: 0.9922
# average test accuracy over 3 runs is: 0.9926
# [0.8380666666666666, 0.9811, 0.9127333333333333, 0.9879666666666665, 0.9467, 0.9926]

# %% [markdown]
# ## mhist

# %% [markdown]
# Read in data from annotation and png

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip  "/content/drive/My Drive/Colab Notebooks/mhist_dataset.zip"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  /content/drive/My Drive/Colab Notebooks/mhist_dataset.zip
# replace mhist_dataset/annotations.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: yes
#   inflating: mhist_dataset/annotations.csv
# replace mhist_dataset/images/MHIST_aaa.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace mhist_dataset/images/MHIST_aaa.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: all
# error:  invalid response [all]
# replace mhist_dataset/images/MHIST_aaa.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: mhist_dataset/images/MHIST_aaa.png
#   inflating: mhist_dataset/images/MHIST_aab.png
#   inflating: mhist_dataset/images/MHIST_aac.png
#   inflating: mhist_dataset/images/MHIST_aad.png
#   inflating: mhist_dataset/images/MHIST_aae.png
#   inflating: mhist_dataset/images/MHIST_aaf.png
#   inflating: mhist_dataset/images/MHIST_aag.png
#   inflating: mhist_dataset/images/MHIST_aah.png
#   inflating: mhist_dataset/images/MHIST_aai.png
#   inflating: mhist_dataset/images/MHIST_aaj.png
#   inflating: mhist_dataset/images/MHIST_aak.png
#   inflating: mhist_dataset/images/MHIST_aal.png
#   inflating: mhist_dataset/images/MHIST_aam.png
#   inflating: mhist_dataset/images/MHIST_aan.png
#   inflating: mhist_dataset/images/MHIST_aao.png
#   inflating: mhist_dataset/images/MHIST_aap.png
#   inflating: mhist_dataset/images/MHIST_aaq.png
#   inflating: mhist_dataset/images/MHIST_aar.png
#   inflating: mhist_dataset/images/MHIST_aas.png
#  extracting: mhist_dataset/images/MHIST_aat.png
#   inflating: mhist_dataset/images/MHIST_aau.png
#   inflating: mhist_dataset/images/MHIST_aav.png
#  extracting: mhist_dataset/images/MHIST_aaw.png
#   inflating: mhist_dataset/images/MHIST_aax.png
#   inflating: mhist_dataset/images/MHIST_aay.png
#   inflating: mhist_dataset/images/MHIST_aaz.png
#   inflating: mhist_dataset/images/MHIST_aba.png
#   inflating: mhist_dataset/images/MHIST_abb.png
#   inflating: mhist_dataset/images/MHIST_abc.png
#   inflating: mhist_dataset/images/MHIST_abd.png
#   inflating: mhist_dataset/images/MHIST_abe.png
#   inflating: mhist_dataset/images/MHIST_abf.png
#  extracting: mhist_dataset/images/MHIST_abg.png
#   inflating: mhist_dataset/images/MHIST_abh.png
#   inflating: mhist_dataset/images/MHIST_abi.png
#   inflating: mhist_dataset/images/MHIST_abj.png
#   inflating: mhist_dataset/images/MHIST_abk.png
#   inflating: mhist_dataset/images/MHIST_abl.png
#   inflating: mhist_dataset/images/MHIST_abm.png
#  extracting: mhist_dataset/images/MHIST_abn.png
#   inflating: mhist_dataset/images/MHIST_abo.png
#   inflating: mhist_dataset/images/MHIST_abp.png
#   inflating: mhist_dataset/images/MHIST_abq.png
#   inflating: mhist_dataset/images/MHIST_abr.png
#   inflating: mhist_dataset/images/MHIST_abs.png
#   inflating: mhist_dataset/images/MHIST_abt.png
#  extracting: mhist_dataset/images/MHIST_abu.png
#   inflating: mhist_dataset/images/MHIST_abv.png
#   inflating: mhist_dataset/images/MHIST_abw.png
#  extracting: mhist_dataset/images/MHIST_abx.png
#   inflating: mhist_dataset/images/MHIST_aby.png
#   inflating: mhist_dataset/images/MHIST_abz.png
#   inflating: mhist_dataset/images/MHIST_aca.png
#   inflating: mhist_dataset/images/MHIST_acb.png
#   inflating: mhist_dataset/images/MHIST_acc.png
#  extracting: mhist_dataset/images/MHIST_acd.png
#  extracting: mhist_dataset/images/MHIST_ace.png
#   inflating: mhist_dataset/images/MHIST_acf.png
#   inflating: mhist_dataset/images/MHIST_acg.png
#   inflating: mhist_dataset/images/MHIST_ach.png
#   inflating: mhist_dataset/images/MHIST_aci.png
#   inflating: mhist_dataset/images/MHIST_acj.png
#   inflating: mhist_dataset/images/MHIST_ack.png
#   inflating: mhist_dataset/images/MHIST_acl.png
#   inflating: mhist_dataset/images/MHIST_acm.png
#   inflating: mhist_dataset/images/MHIST_acn.png
#   inflating: mhist_dataset/images/MHIST_aco.png
#   inflating: mhist_dataset/images/MHIST_acp.png
#   inflating: mhist_dataset/images/MHIST_acq.png
#   inflating: mhist_dataset/images/MHIST_acr.png
#  extracting: mhist_dataset/images/MHIST_acs.png
#   inflating: mhist_dataset/images/MHIST_act.png
#   inflating: mhist_dataset/images/MHIST_acu.png
#  extracting: mhist_dataset/images/MHIST_acv.png
#   inflating: mhist_dataset/images/MHIST_acw.png
#   inflating: mhist_dataset/images/MHIST_acx.png
#   inflating: mhist_dataset/images/MHIST_acy.png
#   inflating: mhist_dataset/images/MHIST_acz.png
#   inflating: mhist_dataset/images/MHIST_ehl.png
#   inflating: mhist_dataset/images/MHIST_ehm.png
#   inflating: mhist_dataset/images/MHIST_ehn.png
#   inflating: mhist_dataset/images/MHIST_eho.png
#   inflating: mhist_dataset/images/MHIST_ehp.png
#   inflating: mhist_dataset/images/MHIST_ehq.png
#   inflating: mhist_dataset/images/MHIST_ehr.png
#   inflating: mhist_dataset/images/MHIST_ehs.png
#   inflating: mhist_dataset/images/MHIST_eht.png
#   inflating: mhist_dataset/images/MHIST_ehu.png
#   inflating: mhist_dataset/images/MHIST_ehv.png
#  extracting: mhist_dataset/images/MHIST_ehw.png
#  extracting: mhist_dataset/images/MHIST_ehx.png
#   inflating: mhist_dataset/images/MHIST_ehy.png
#   inflating: mhist_dataset/images/MHIST_ehz.png
#   inflating: mhist_dataset/images/MHIST_eia.png
#   inflating: mhist_dataset/images/MHIST_eib.png
#   inflating: mhist_dataset/images/MHIST_eic.png
#   inflating: mhist_dataset/images/MHIST_eid.png
#   inflating: mhist_dataset/images/MHIST_eie.png
#   inflating: mhist_dataset/images/MHIST_eif.png
#   inflating: mhist_dataset/images/MHIST_eig.png
#   inflating: mhist_dataset/images/MHIST_eih.png
#   inflating: mhist_dataset/images/MHIST_eii.png
#   inflating: mhist_dataset/images/MHIST_eij.png
#   inflating: mhist_dataset/images/MHIST_eik.png
#   inflating: mhist_dataset/images/MHIST_eil.png
#  extracting: mhist_dataset/images/MHIST_eim.png
#   inflating: mhist_dataset/images/MHIST_ein.png
#  extracting: mhist_dataset/images/MHIST_eio.png
#   inflating: mhist_dataset/images/MHIST_eip.png
#   inflating: mhist_dataset/images/MHIST_eiq.png
#   inflating: mhist_dataset/images/MHIST_eir.png
#   inflating: mhist_dataset/images/MHIST_eis.png
#   inflating: mhist_dataset/images/MHIST_eit.png
#   inflating: mhist_dataset/images/MHIST_eiu.png
#   inflating: mhist_dataset/images/MHIST_eiv.png
#   inflating: mhist_dataset/images/MHIST_eiw.png
#   inflating: mhist_dataset/images/MHIST_eix.png
#   inflating: mhist_dataset/images/MHIST_eiy.png
#  extracting: mhist_dataset/images/MHIST_eiz.png
#   inflating: mhist_dataset/images/MHIST_eja.png
#   inflating: mhist_dataset/images/MHIST_ejb.png
#   inflating: mhist_dataset/images/MHIST_ejc.png
#   inflating: mhist_dataset/images/MHIST_ejd.png
#   inflating: mhist_dataset/images/MHIST_eje.png
#   inflating: mhist_dataset/images/MHIST_ejf.png
#  extracting: mhist_dataset/images/MHIST_ejg.png
#   inflating: mhist_dataset/images/MHIST_ejh.png
#  extracting: mhist_dataset/images/MHIST_eji.png
#   inflating: mhist_dataset/images/MHIST_ejj.png
#   inflating: mhist_dataset/images/MHIST_ejk.png
#  extracting: mhist_dataset/images/MHIST_ejl.png
#   inflating: mhist_dataset/images/MHIST_ejm.png
#   inflating: mhist_dataset/images/MHIST_ejn.png
#   inflating: mhist_dataset/images/MHIST_ejo.png
#   inflating: mhist_dataset/images/MHIST_ejp.png
#   inflating: mhist_dataset/images/MHIST_ejq.png
#   inflating: mhist_dataset/images/MHIST_elx.png
#   inflating: mhist_dataset/images/MHIST_ely.png
#   inflating: mhist_dataset/images/MHIST_elz.png
#   inflating: mhist_dataset/images/MHIST_ema.png
#   inflating: mhist_dataset/images/MHIST_emb.png
#   inflating: mhist_dataset/images/MHIST_emc.png
#   inflating: mhist_dataset/images/MHIST_emd.png
#   inflating: mhist_dataset/images/MHIST_eme.png
#   inflating: mhist_dataset/images/MHIST_emf.png
#   inflating: mhist_dataset/images/MHIST_emg.png
#   inflating: mhist_dataset/images/MHIST_emh.png
#   inflating: mhist_dataset/images/MHIST_emi.png
#   inflating: mhist_dataset/images/MHIST_emj.png
#   inflating: mhist_dataset/images/MHIST_emk.png
#  extracting: mhist_dataset/images/MHIST_eml.png
#   inflating: mhist_dataset/images/MHIST_emm.png
#   inflating: mhist_dataset/images/MHIST_emn.png
#  extracting: mhist_dataset/images/MHIST_emo.png
#   inflating: mhist_dataset/images/MHIST_emp.png
#   inflating: mhist_dataset/images/MHIST_emq.png
#  extracting: mhist_dataset/images/MHIST_emr.png
#   inflating: mhist_dataset/images/MHIST_ems.png
#   inflating: mhist_dataset/images/MHIST_emt.png
#   inflating: mhist_dataset/images/MHIST_emu.png
#   inflating: mhist_dataset/images/MHIST_emv.png
#   inflating: mhist_dataset/images/MHIST_emw.png
#   inflating: mhist_dataset/images/MHIST_emx.png
#   inflating: mhist_dataset/images/MHIST_emy.png
#   inflating: mhist_dataset/images/MHIST_emz.png
#   inflating: mhist_dataset/images/MHIST_ena.png
#   inflating: mhist_dataset/images/MHIST_enb.png
#   inflating: mhist_dataset/images/MHIST_enc.png
#   inflating: mhist_dataset/images/MHIST_end.png
#   inflating: mhist_dataset/images/MHIST_ene.png
#   inflating: mhist_dataset/images/MHIST_enf.png
#   inflating: mhist_dataset/images/MHIST_eng.png
#  extracting: mhist_dataset/images/MHIST_enh.png
#   inflating: mhist_dataset/images/MHIST_eni.png
#   inflating: mhist_dataset/images/MHIST_enj.png
#   inflating: mhist_dataset/images/MHIST_enk.png
#   inflating: mhist_dataset/images/MHIST_enl.png
#   inflating: mhist_dataset/images/MHIST_enm.png
#   inflating: mhist_dataset/images/MHIST_enn.png
#   inflating: mhist_dataset/images/MHIST_eno.png
#   inflating: mhist_dataset/images/MHIST_enp.png
#   inflating: mhist_dataset/images/MHIST_enq.png
#   inflating: mhist_dataset/images/MHIST_enr.png
#   inflating: mhist_dataset/images/MHIST_ens.png
#   inflating: mhist_dataset/images/MHIST_ent.png
#   inflating: mhist_dataset/images/MHIST_enu.png
#   inflating: mhist_dataset/images/MHIST_env.png
#   inflating: mhist_dataset/images/MHIST_enw.png
#   inflating: mhist_dataset/images/MHIST_enx.png
#   inflating: mhist_dataset/images/MHIST_eny.png
#  extracting: mhist_dataset/images/MHIST_enz.png
#   inflating: mhist_dataset/images/MHIST_eoa.png
#   inflating: mhist_dataset/images/MHIST_eob.png
#  extracting: mhist_dataset/images/MHIST_eoc.png
#  extracting: mhist_dataset/images/MHIST_eod.png
#   inflating: mhist_dataset/images/MHIST_eoe.png
#   inflating: mhist_dataset/images/MHIST_eof.png
#  extracting: mhist_dataset/images/MHIST_eog.png
#   inflating: mhist_dataset/images/MHIST_eoh.png
#   inflating: mhist_dataset/images/MHIST_eoi.png
#   inflating: mhist_dataset/images/MHIST_eoj.png
#  extracting: mhist_dataset/images/MHIST_eok.png
#   inflating: mhist_dataset/images/MHIST_eol.png
#   inflating: mhist_dataset/images/MHIST_eom.png
#  extracting: mhist_dataset/images/MHIST_eon.png
#   inflating: mhist_dataset/images/MHIST_eoo.png
#   inflating: mhist_dataset/images/MHIST_eop.png
#  extracting: mhist_dataset/images/MHIST_eoq.png
#   inflating: mhist_dataset/images/MHIST_eor.png
#  extracting: mhist_dataset/images/MHIST_eos.png
#   inflating: mhist_dataset/images/MHIST_eot.png
#   inflating: mhist_dataset/images/MHIST_eou.png
#   inflating: mhist_dataset/images/MHIST_eov.png
#   inflating: mhist_dataset/images/MHIST_eow.png
#   inflating: mhist_dataset/images/MHIST_eox.png
#  extracting: mhist_dataset/images/MHIST_eoy.png
#   inflating: mhist_dataset/images/MHIST_eoz.png
#   inflating: mhist_dataset/images/MHIST_epa.png
#   inflating: mhist_dataset/images/MHIST_epb.png
#   inflating: mhist_dataset/images/MHIST_epc.png
#   inflating: mhist_dataset/images/MHIST_epd.png
#   inflating: mhist_dataset/images/MHIST_epe.png
#   inflating: mhist_dataset/images/MHIST_epf.png
#   inflating: mhist_dataset/images/MHIST_epg.png
#   inflating: mhist_dataset/images/MHIST_eph.png
#   inflating: mhist_dataset/images/MHIST_epi.png
#   inflating: mhist_dataset/images/MHIST_epj.png
#   inflating: mhist_dataset/images/MHIST_epk.png
#   inflating: mhist_dataset/images/MHIST_epl.png
#   inflating: mhist_dataset/images/MHIST_epm.png
#   inflating: mhist_dataset/images/MHIST_epn.png
#   inflating: mhist_dataset/images/MHIST_epo.png
#   inflating: mhist_dataset/images/MHIST_epp.png
#   inflating: mhist_dataset/images/MHIST_epq.png
#   inflating: mhist_dataset/images/MHIST_epr.png
#   inflating: mhist_dataset/images/MHIST_eps.png
#   inflating: mhist_dataset/images/MHIST_ept.png
#  extracting: mhist_dataset/images/MHIST_epu.png
#  extracting: mhist_dataset/images/MHIST_epv.png
#   inflating: mhist_dataset/images/MHIST_epw.png
#   inflating: mhist_dataset/images/MHIST_epx.png
#   inflating: mhist_dataset/images/MHIST_epy.png
#   inflating: mhist_dataset/images/MHIST_epz.png
#   inflating: mhist_dataset/images/MHIST_eqa.png
#  extracting: mhist_dataset/images/MHIST_eqb.png
#   inflating: mhist_dataset/images/MHIST_eqc.png
#   inflating: mhist_dataset/images/MHIST_eqd.png
#   inflating: mhist_dataset/images/MHIST_eqe.png
#   inflating: mhist_dataset/images/MHIST_eqf.png
#   inflating: mhist_dataset/images/MHIST_eqg.png
#   inflating: mhist_dataset/images/MHIST_eqh.png
#  extracting: mhist_dataset/images/MHIST_eqi.png
#   inflating: mhist_dataset/images/MHIST_eqj.png
#   inflating: mhist_dataset/images/MHIST_eqk.png
#  extracting: mhist_dataset/images/MHIST_eql.png
#   inflating: mhist_dataset/images/MHIST_eqm.png
#   inflating: mhist_dataset/images/MHIST_eqn.png
#   inflating: mhist_dataset/images/MHIST_eqo.png
#   inflating: mhist_dataset/images/MHIST_eqp.png
#   inflating: mhist_dataset/images/MHIST_eqq.png
#   inflating: mhist_dataset/images/MHIST_eqr.png
#   inflating: mhist_dataset/images/MHIST_eqs.png
#   inflating: mhist_dataset/images/MHIST_eqt.png
#   inflating: mhist_dataset/images/MHIST_equ.png
#  extracting: mhist_dataset/images/MHIST_eqv.png
#   inflating: mhist_dataset/images/MHIST_eqw.png
#   inflating: mhist_dataset/images/MHIST_eqx.png
#   inflating: mhist_dataset/images/MHIST_eqy.png
#   inflating: mhist_dataset/images/MHIST_eqz.png
#   inflating: mhist_dataset/images/MHIST_era.png
#   inflating: mhist_dataset/images/MHIST_erb.png
#   inflating: mhist_dataset/images/MHIST_erc.png
#   inflating: mhist_dataset/images/MHIST_erd.png
#   inflating: mhist_dataset/images/MHIST_ere.png
#   inflating: mhist_dataset/images/MHIST_erf.png

# %%
import torch
import numpy as np
import csv
from torch.utils.data import Dataset
from torchvision import transforms

class MHISTDataset(Dataset):
  def __init__(self, images, labels, mean, std): 
      self.images = images
      self.labels = labels
      self.mean = mean
      self.std = std

  def __getitem__(self, idx):

        data = self.images[idx]
        label = self.labels[idx]
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)
        ])
        return transform(data), label

  def __len__(self):
      return len(self.labels)

def getMHIST():
  # csv file name
  filename = "mhist_dataset/annotations.csv"
  import cv2
  
  # initializing the titles and rows list
  fields = []
  rows = []
  path = "mhist_dataset/images/"
  
  # reading csv file
  with open(filename, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
      
    # extracting field names through first row
    fields = next(csvreader)
  
    # extracting each data row one by one
    for row in csvreader:
      rows.append(row)
  


  #label HP = 0 SSA = 1


  training_image = []
  training_label = []
  testing_image = []
  testing_label = []

  mean = np.array([0.,0.,0.])
  stdTemp = np.array([0.,0.,0.])
  std = np.array([0.,0.,0.])


  for row in rows:
    # parsing each column of a row
    img_path = path + row[0]
    image = cv2.imread(img_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image.astype(float) / 255.
    # for j in range(3):
    #     mean[j] += np.mean(image[:,:,j])
    label = 0
    if row[1] == "SSA":
      label = 1
      
    if row[3] == "train":
      training_image.append(image)
      training_label.append(label)

    elif row[3] == "test":
      testing_image.append(image)
      testing_label.append(label)

  print("Training Label: ")  
  print(len(training_label))
  print("Testing Label: ")
  print(len(testing_label))

  # mean = (mean/len(rows))
  # print(mean)


  
  # for row in rows:
  #   # parsing each column of a row
  #   img_path = path + row[0]
  #   image = cv2.imread(img_path)
  #   image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  #   image = image.astype(float) / 255.

  #   for j in range(3):
  #     stdTemp[j] += ((image[:,:,j] - mean[j])**2).sum()/(image.shape[0]*image.shape[1])

  # std = np.sqrt(stdTemp/len(rows))
  # print(std)




  channel = 3
  im_size = (224, 224)
  num_classes = 2
  class_names = ['HP', 'SSA']
  mean = [0.73943309, 0.65267006, 0.77742641]
  std = [0.19637706, 0.24239548, 0.16935587]


  dst_train = MHISTDataset(training_image, training_label, mean, std) 

  dst_test = MHISTDataset(testing_image, testing_label, mean, std)
  testloader = torch.utils.data.DataLoader(dst_test, batch_size=256, shuffle=False, num_workers=0)

  return channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader

#training_image = tf.convert_to_tensor(np.array(training_image))
#testing_image = tf.convert_to_tensor(np.array(testing_image))
#training_label = tf.convert_to_tensor(np.array(training_label))
#testing_label = tf.convert_to_tensor(np.array(testing_label))

# %%
getMHIST()
# Out:
# Training Label:
# 77
# Testing Label:
# 23
# [0.02350418 0.02076763 0.02470523]
# [0.13253466 0.12098372 0.13772575]
# (3,
#  (224, 224),
#  2,
#  ['HP', 'SSA'],
#  array([0.02350418, 0.02076763, 0.02470523]),
#  array([0.13253466, 0.12098372, 0.13772575]),
#  <__main__.TensorDataset at 0x7f45e8fc7400>,
#  <__main__.TensorDataset at 0x7f45e8fc7490>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f45e8fc7fa0>)

# %%
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image
import time 


class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'MNIST'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 16
    self.batch_train = 16
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'



args = myArgs()
args.outer_loop, args.inner_loop = get_loops(args.ipc)
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
args.dsa_param = ParamDiffAug()
args.dsa = True if args.method == 'DSA' else False


channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = getMHIST()
#channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)

net = get_network(args.model, channel, num_classes, im_size).to(args.device)

net.train()
optimizer_net = torch.optim.SGD(net.parameters(), lr=0.01)  # optimizer_img for synthetic data
optimizer_net.zero_grad()

criterion = nn.CrossEntropyLoss().to(args.device)

num_epochs = 20

trainloader = torch.utils.data.DataLoader(dst_train, batch_size=args.batch_train, shuffle=True, num_workers=0)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_net, num_epochs)

start = time.time()

for i in range(num_epochs):
  loss_avg, acc_avg = epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
  for param_group in optimizer_net.param_groups:
    print("Current learning rate is: {}".format(param_group['lr']))

  print("Epoch[{}/{}]: Loss: {:.4f}, ACC: {:.4f}".format(i+1,num_epochs, loss_avg, acc_avg))
  scheduler.step()

print(time.time() - start)

testloader = torch.utils.data.DataLoader(dst_test, batch_size=args.batch_train, shuffle=True, num_workers=0)
net.eval()
loss_avg, acc_avg = epoch('test', testloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)

print("Test set: Loss: {:.4f}, ACC: {:.4f}".format(loss_avg, acc_avg))
# Out:
# importing Jupyter notebook from utils.ipynb
# importing Jupyter notebook from networks.ipynb
# Training Label:
# 2175
# Testing Label:
# 977
# Current learning rate is: 0.01
# Epoch[1/20]: Loss: 13.1348, ACC: 0.6000
# Current learning rate is: 0.009938441702975689
# Epoch[2/20]: Loss: 1.4539, ACC: 0.7140
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-397e26a8aadb> in <module>
#      56
#      57 for i in range(num_epochs):
# ---> 58   loss_avg, acc_avg = epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)
#      59   for param_group in optimizer_net.param_groups:
#      60     print("Current learning rate is: {}".format(param_group['lr']))
#
# /content/utils.ipynb in epoch(mode, dataloader, net, optimizer, criterion, args, aug)
#
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
import os
import time
import copy
import argparse
import numpy as np
import torch
import torch.nn as nn
from torchvision.utils import save_image
from utils import get_loops, get_dataset, get_network, get_eval_pool, evaluate_synset, get_daparam, match_loss, get_time, TensorDataset, epoch, DiffAugment, ParamDiffAug


class myArgs:
  def __init__(self):
    self.method = 'DC'
    self.dataset = 'MNIST'
    self.model = 'ConvNet'
    self.ipc = 10
    self.eval_mode = 'S'
    self.num_exp = 1
    self.num_eval = 5
    self.epoch_eval_train = 300
    self.Iteration = 100
    self.lr_img = 0.1
    self.lr_net = 0.01
    self.batch_real = 16
    self.batch_train = 16
    self.init = 'real'
    self.dsa_strategy = 'None'
    self.data_path = 'data'
    self.save_path = 'result'
    self.dis_metric = 'ours'

def main():

    # parser = argparse.ArgumentParser(description='Parameter Processing')
    # parser.add_argument('--method', type=str, default='DC', help='DC/DSA')
    # parser.add_argument('--dataset', type=str, default='CIFAR10', help='dataset')
    # parser.add_argument('--model', type=str, default='ConvNet', help='model')
    # parser.add_argument('--ipc', type=int, default=1, help='image(s) per class')
    # parser.add_argument('--eval_mode', type=str, default='S', help='eval_mode') # S: the same to training model, M: multi architectures,  W: net width, D: net depth, A: activation function, P: pooling layer, N: normalization layer,
    # parser.add_argument('--num_exp', type=int, default=5, help='the number of experiments')
    # parser.add_argument('--num_eval', type=int, default=20, help='the number of evaluating randomly initialized models')
    # parser.add_argument('--epoch_eval_train', type=int, default=300, help='epochs to train a model with synthetic data')
    # parser.add_argument('--Iteration', type=int, default=1000, help='training iterations')
    # parser.add_argument('--lr_img', type=float, default=0.1, help='learning rate for updating synthetic images')
    # parser.add_argument('--lr_net', type=float, default=0.01, help='learning rate for updating network parameters')
    # parser.add_argument('--batch_real', type=int, default=256, help='batch size for real data')
    # parser.add_argument('--batch_train', type=int, default=256, help='batch size for training networks')
    # parser.add_argument('--init', type=str, default='noise', help='noise/real: initialize synthetic images from random noise or randomly sampled real images.')
    # parser.add_argument('--dsa_strategy', type=str, default='None', help='differentiable Siamese augmentation strategy')
    # parser.add_argument('--data_path', type=str, default='data', help='dataset path')
    # parser.add_argument('--save_path', type=str, default='result', help='path to save results')
    # parser.add_argument('--dis_metric', type=str, default='ours', help='distance metric')

    # args = parser.parse_args()
    args = myArgs()
    args.outer_loop, args.inner_loop = get_loops(args.ipc)
    args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
    args.dsa_param = ParamDiffAug()
    args.dsa = True if args.method == 'DSA' else False


    if not os.path.exists(args.data_path):
        os.mkdir(args.data_path)

    if not os.path.exists(args.save_path):
        os.mkdir(args.save_path)

    eval_it_pool = np.arange(0, args.Iteration+1, 20).tolist() if args.eval_mode == 'S' or args.eval_mode == 'SS' else [args.Iteration] # The list of iterations when we evaluate models and record results.
    print('eval_it_pool: ', eval_it_pool)
    channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = getMHIST()
    #channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader = get_dataset(args.dataset, args.data_path)
    model_eval_pool = get_eval_pool(args.eval_mode, args.model, args.model)


    accs_all_exps = dict() # record performances of all experiments
    for key in model_eval_pool:
        accs_all_exps[key] = []

    data_save = []


    for exp in range(args.num_exp):
        print('\n================== Exp %d ==================\n '%exp)
        print('Hyper-parameters: \n', args.__dict__)
        print('Evaluation model pool: ', model_eval_pool)

        ''' organize the real dataset '''
        images_all = []
        labels_all = []
        indices_class = [[] for c in range(num_classes)]

        images_all = [torch.unsqueeze(dst_train[i][0], dim=0) for i in range(len(dst_train))]
        labels_all = [dst_train[i][1] for i in range(len(dst_train))]
        for i, lab in enumerate(labels_all):
            indices_class[lab].append(i)

        images_all = torch.cat(images_all, dim=0).to(args.device)
        labels_all = torch.tensor(labels_all, dtype=torch.long, device=args.device)

        for c in range(num_classes):
            print('class c = %d: %d real images'%(c, len(indices_class[c])))

        def get_images(c, n): # get random n images from class c
            idx_shuffle = np.random.permutation(indices_class[c])[:n]
            return images_all[idx_shuffle]

        for ch in range(channel):
            print('real images channel %d, mean = %.4f, std = %.4f'%(ch, torch.mean(images_all[:, ch]), torch.std(images_all[:, ch])))


        ''' initialize the synthetic data '''
        image_syn = torch.randn(size=(num_classes*args.ipc, channel, im_size[0], im_size[1]), dtype=torch.float, requires_grad=True, device=args.device)
        label_syn = torch.tensor([np.ones(args.ipc)*i for i in range(num_classes)], dtype=torch.long, requires_grad=False, device=args.device).view(-1) # [0,0,0, 1,1,1, ..., 9,9,9]

        if args.init == 'real':
            print('initialize synthetic data from random real images')
            for c in range(num_classes):
                image_syn.data[c*args.ipc:(c+1)*args.ipc] = get_images(c, args.ipc).detach().data
        else:
            print('initialize synthetic data from random noise')


        ''' training '''
        optimizer_img = torch.optim.SGD([image_syn, ], lr=args.lr_img, momentum=0.5) # optimizer_img for synthetic data
        optimizer_img.zero_grad()
        criterion = nn.CrossEntropyLoss().to(args.device)
        print('%s training begins'%get_time())

        for it in range(args.Iteration+1):

            ''' Evaluate synthetic data '''
            if it in eval_it_pool:
                for model_eval in model_eval_pool:
                    print('-------------------------\nEvaluation\nmodel_train = %s, model_eval = %s, iteration = %d'%(args.model, model_eval, it))
                    if args.dsa:
                        args.epoch_eval_train = 1000
                        args.dc_aug_param = None
                        print('DSA augmentation strategy: \n', args.dsa_strategy)
                        print('DSA augmentation parameters: \n', args.dsa_param.__dict__)
                    else:
                        args.dc_aug_param = get_daparam(args.dataset, args.model, model_eval, args.ipc) # This augmentation parameter set is only for DC method. It will be muted when args.dsa is True.
                        print('DC augmentation parameters: \n', args.dc_aug_param)

                    if args.dsa or args.dc_aug_param['strategy'] != 'none':
                        args.epoch_eval_train = 1000  # Training with data augmentation needs more epochs.
                    else:
                        args.epoch_eval_train = 300
                    
                    args.epoch_eval_train = 300

                    accs = []
                    for it_eval in range(args.num_eval):
                        net_eval = get_network(model_eval, channel, num_classes, im_size).to(args.device) # get a random model
                        image_syn_eval, label_syn_eval = copy.deepcopy(image_syn.detach()), copy.deepcopy(label_syn.detach()) # avoid any unaware modification
                        _, acc_train, acc_test = evaluate_synset(it_eval, net_eval, image_syn_eval, label_syn_eval, testloader, args)
                        accs.append(acc_test)
                    print('Evaluate %d random %s, mean = %.4f std = %.4f\n-------------------------'%(len(accs), model_eval, np.mean(accs), np.std(accs)))

                    if it == args.Iteration: # record the final results
                        accs_all_exps[model_eval] += accs

                ''' visualize and save '''
                save_name = os.path.join(args.save_path, 'vis_%s_%s_%s_%dipc_exp%d_iter%d.png'%(args.method, args.dataset, args.model, args.ipc, exp, it))
                image_syn_vis = copy.deepcopy(image_syn.detach().cpu())
                for ch in range(channel):
                    image_syn_vis[:, ch] = image_syn_vis[:, ch]  * std[ch] + mean[ch]
                image_syn_vis[image_syn_vis<0] = 0.0
                image_syn_vis[image_syn_vis>1] = 1.0
                save_image(image_syn_vis, save_name, nrow=args.ipc) # Trying normalize = True/False may get better visual effects.


            ''' Train synthetic data '''
            net = get_network(args.model, channel, num_classes, im_size).to(args.device) # get a random model
            net.train()
            net_parameters = list(net.parameters())
            optimizer_net = torch.optim.SGD(net.parameters(), lr=args.lr_net)  # optimizer_img for synthetic data
            optimizer_net.zero_grad()
            loss_avg = 0
            args.dc_aug_param = None  # Mute the DC augmentation when learning synthetic data (in inner-loop epoch function) in oder to be consistent with DC paper.


            for ol in range(args.outer_loop):

                ''' freeze the running mu and sigma for BatchNorm layers '''
                # Synthetic data batch, e.g. only 1 image/batch, is too small to obtain stable mu and sigma.
                # So, we calculate and freeze mu and sigma for BatchNorm layer with real data batch ahead.
                # This would make the training with BatchNorm layers easier.

                BN_flag = False
                BNSizePC = 16  # for batch normalization
                for module in net.modules():
                    if 'BatchNorm' in module._get_name(): #BatchNorm
                        BN_flag = True
                if BN_flag:
                    img_real = torch.cat([get_images(c, BNSizePC) for c in range(num_classes)], dim=0)
                    net.train() # for updating the mu, sigma of BatchNorm
                    output_real = net(img_real) # get running mu, sigma
                    for module in net.modules():
                        if 'BatchNorm' in module._get_name():  #BatchNorm
                            module.eval() # fix mu and sigma of every BatchNorm layer


                ''' update synthetic data '''
                loss = torch.tensor(0.0).to(args.device)
                for c in range(num_classes):
                    img_real = get_images(c, args.batch_real)
                    lab_real = torch.ones((img_real.shape[0],), device=args.device, dtype=torch.long) * c
                    img_syn = image_syn[c*args.ipc:(c+1)*args.ipc].reshape((args.ipc, channel, im_size[0], im_size[1]))
                    lab_syn = torch.ones((args.ipc,), device=args.device, dtype=torch.long) * c

                    if args.dsa:
                        seed = int(time.time() * 1000) % 100000
                        img_real = DiffAugment(img_real, args.dsa_strategy, seed=seed, param=args.dsa_param)
                        img_syn = DiffAugment(img_syn, args.dsa_strategy, seed=seed, param=args.dsa_param)

                    output_real = net(img_real)
                    loss_real = criterion(output_real, lab_real)
                    gw_real = torch.autograd.grad(loss_real, net_parameters)
                    gw_real = list((_.detach().clone() for _ in gw_real))

                    output_syn = net(img_syn)
                    loss_syn = criterion(output_syn, lab_syn)
                    gw_syn = torch.autograd.grad(loss_syn, net_parameters, create_graph=True)

                    loss += match_loss(gw_syn, gw_real, args)

                optimizer_img.zero_grad()
                loss.backward()
                optimizer_img.step()
                loss_avg += loss.item()

                if ol == args.outer_loop - 1:
                    break


                ''' update network '''
                image_syn_train, label_syn_train = copy.deepcopy(image_syn.detach()), copy.deepcopy(label_syn.detach())  # avoid any unaware modification
                dst_syn_train = TensorDataset(image_syn_train, label_syn_train)
                trainloader = torch.utils.data.DataLoader(dst_syn_train, batch_size=args.batch_train, shuffle=True, num_workers=0)
                for il in range(args.inner_loop):
                    epoch('train', trainloader, net, optimizer_net, criterion, args, aug = True if args.dsa else False)


            loss_avg /= (num_classes*args.outer_loop)

            if it%10 == 0:
                print('%s iter = %04d, loss = %.4f' % (get_time(), it, loss_avg))

            if it == args.Iteration: # only record the final results
                data_save.append([copy.deepcopy(image_syn.detach().cpu()), copy.deepcopy(label_syn.detach().cpu())])
                torch.save({'data': data_save, 'accs_all_exps': accs_all_exps, }, os.path.join(args.save_path, 'res_%s_%s_%s_%dipc.pt'%(args.method, args.dataset, args.model, args.ipc)))


    print('\n==================== Final Results ====================\n')
    for key in model_eval_pool:
        accs = accs_all_exps[key]
        print('Run %d experiments, train on %s, evaluate %d random %s, mean  = %.2f%%  std = %.2f%%'%(args.num_exp, args.model, len(accs), key, np.mean(accs)*100, np.std(accs)*100))


main()
# Out:
# eval_it_pool:  [0, 20, 40, 60, 80, 100]
# Training Label:
# 2175
# Testing Label:
# 977
#
# ================== Exp 0 ==================
#
# Hyper-parameters:
#  {'method': 'DC', 'dataset': 'MNIST', 'model': 'ConvNet', 'ipc': 10, 'eval_mode': 'S', 'num_exp': 1, 'num_eval': 5, 'epoch_eval_train': 300, 'Iteration': 100, 'lr_img': 0.1, 'lr_net': 0.01, 'batch_real': 16, 'batch_train': 16, 'init': 'real', 'dsa_strategy': 'None', 'data_path': 'data', 'save_path': 'result', 'dis_metric': 'ours', 'outer_loop': 10, 'inner_loop': 50, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7f596ef6c7f0>, 'dsa': False}
# Evaluation model pool:  ['ConvNet']
