# %%
# !pip install import_ipynb
import import_ipynb
# !pip install kornia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import_ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from import_ipynb) (5.7.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from import_ipynb) (7.9.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (57.4.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from IPython->import_ipynb) (2.0.10)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 13.0 MB/s
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import_ipynb) (1.15.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import_ipynb) (4.3.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import_ipynb) (4.13.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->import_ipynb) (2.16.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->import_ipynb) (4.11.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->nbformat->import_ipynb) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->nbformat->import_ipynb) (3.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (5.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->import_ipynb) (0.7.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.18.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kornia
#   Downloading kornia-0.6.8-py2.py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 14.9 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from kornia) (21.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from kornia) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.8.1->kornia) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->kornia) (3.0.9)
# Installing collected packages: kornia
# Successfully installed kornia-0.6.8

# %%
import os
import argparse
import torch
import torch.nn as nn
from tqdm import tqdm
from utils import get_dataset, get_network, get_daparam,\
    TensorDataset, epoch, ParamDiffAug
import copy

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

class myArgs:
  def __init__(self):
    self.dataset = 'CIFAR10'
    self.subset = 'imagenette'
    self.model = 'ConvNet'
    self.num_experts = 10
    self.lr_teacher = 0.01
    self.batch_train = 256
    self.batch_real = 256
    self.dsa = 'False'
    self.dsa_strategy = 'color_crop_cutout_flip_scale_rotate'
    self.data_path = 'data'
    self.buffer_path = './buffers'
    self.train_epochs = 20
    self.zca = False
    self.decay = False
    self.mom = 0
    self.l2 = 0
    self.save_interval = 5


def main():

    args = myArgs()

    args.dsa = True if args.dsa == 'True' else False
    args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
    args.dsa_param = ParamDiffAug()

    channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader, loader_train_dict, class_map, class_map_inv = get_dataset(args.dataset, args.data_path, args.batch_real, args.subset, args=args)

    # print('\n================== Exp %d ==================\n '%exp)
    print('Hyper-parameters: \n', args.__dict__)

    save_dir = os.path.join(args.buffer_path, args.dataset)
    if args.dataset == "ImageNet":
        save_dir = os.path.join(save_dir, args.subset, str(args.res))
    if args.dataset in ["CIFAR10", "CIFAR100"] and not args.zca:
        save_dir += "_NO_ZCA"
    save_dir = os.path.join(save_dir, args.model)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)


    ''' organize the real dataset '''
    images_all = []
    labels_all = []
    indices_class = [[] for c in range(num_classes)]
    print("BUILDING DATASET")
    for i in tqdm(range(len(dst_train))):
        sample = dst_train[i]
        images_all.append(torch.unsqueeze(sample[0], dim=0))
        labels_all.append(class_map[torch.tensor(sample[1]).item()])

    for i, lab in tqdm(enumerate(labels_all)):
        indices_class[lab].append(i)
    images_all = torch.cat(images_all, dim=0).to("cpu")
    labels_all = torch.tensor(labels_all, dtype=torch.long, device="cpu")

    for c in range(num_classes):
        print('class c = %d: %d real images'%(c, len(indices_class[c])))

    for ch in range(channel):
        print('real images channel %d, mean = %.4f, std = %.4f'%(ch, torch.mean(images_all[:, ch]), torch.std(images_all[:, ch])))

    criterion = nn.CrossEntropyLoss().to(args.device)

    trajectories = []

    dst_train = TensorDataset(copy.deepcopy(images_all.detach()), copy.deepcopy(labels_all.detach()))
    trainloader = torch.utils.data.DataLoader(dst_train, batch_size=args.batch_train, shuffle=True, num_workers=0)

    ''' set augmentation for whole-dataset training '''
    args.dc_aug_param = get_daparam(args.dataset, args.model, args.model, None)
    args.dc_aug_param['strategy'] = 'crop_scale_rotate'  # for whole-dataset training
    print('DC augmentation parameters: \n', args.dc_aug_param)

    for it in range(0, args.num_experts):

        ''' Train synthetic data '''
        teacher_net = get_network(args.model, channel, num_classes, im_size).to(args.device) # get a random model
        teacher_net.train()
        lr = args.lr_teacher
        teacher_optim = torch.optim.SGD(teacher_net.parameters(), lr=lr, momentum=args.mom, weight_decay=args.l2)  # optimizer_img for synthetic data
        teacher_optim.zero_grad()

        timestamps = []

        timestamps.append([p.detach().cpu() for p in teacher_net.parameters()])

        lr_schedule = [args.train_epochs // 2 + 1]

        for e in range(args.train_epochs):

            train_loss, train_acc = epoch("train", dataloader=trainloader, net=teacher_net, optimizer=teacher_optim,
                                        criterion=criterion, args=args, aug=True)

            test_loss, test_acc = epoch("test", dataloader=testloader, net=teacher_net, optimizer=None,
                                        criterion=criterion, args=args, aug=False)

            print("Itr: {}\tEpoch: {}\tTrain Acc: {}\tTest Acc: {}".format(it, e, train_acc, test_acc))

            timestamps.append([p.detach().cpu() for p in teacher_net.parameters()])

            if e in lr_schedule and args.decay:
                lr *= 0.1
                teacher_optim = torch.optim.SGD(teacher_net.parameters(), lr=lr, momentum=args.mom, weight_decay=args.l2)
                teacher_optim.zero_grad()

        trajectories.append(timestamps)

        if len(trajectories) == args.save_interval:
            n = 0
            while os.path.exists(os.path.join(save_dir, "replay_buffer_{}.pt".format(n))):
                n += 1
            print("Saving {}".format(os.path.join(save_dir, "replay_buffer_{}.pt".format(n))))
            torch.save(trajectories, os.path.join(save_dir, "replay_buffer_{}.pt".format(n)))
            trajectories = []

# %%
main()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Hyper-parameters:
#  {'dataset': 'CIFAR10', 'subset': 'imagenette', 'model': 'ConvNet', 'num_experts': 10, 'lr_teacher': 0.01, 'batch_train': 256, 'batch_real': 256, 'dsa': False, 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': 'data', 'buffer_path': './buffers', 'train_epochs': 20, 'zca': False, 'decay': False, 'mom': 0, 'l2': 0, 'save_interval': 5, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7fc56393efd0>}
# BUILDING DATASET
# 100%|██████████| 50000/50000 [00:11<00:00, 4188.96it/s]
# 50000it [00:00, 2410048.61it/s]
# class c = 0: 5000 real images
# class c = 1: 5000 real images
# class c = 2: 5000 real images
# class c = 3: 5000 real images
# class c = 4: 5000 real images
# class c = 5: 5000 real images
# class c = 6: 5000 real images
# Itr: 9	Epoch: 5	Train Acc: 0.57488	Test Acc: 0.6053
# Itr: 9	Epoch: 6	Train Acc: 0.59318	Test Acc: 0.6032
# Itr: 9	Epoch: 7	Train Acc: 0.6055	Test Acc: 0.6135
# Itr: 9	Epoch: 8	Train Acc: 0.62088	Test Acc: 0.6409
# Itr: 9	Epoch: 9	Train Acc: 0.63298	Test Acc: 0.622
# Itr: 9	Epoch: 10	Train Acc: 0.6381	Test Acc: 0.6396
# Itr: 9	Epoch: 11	Train Acc: 0.64758	Test Acc: 0.6619
# Itr: 9	Epoch: 12	Train Acc: 0.6564	Test Acc: 0.6687
# Itr: 9	Epoch: 13	Train Acc: 0.6621	Test Acc: 0.6664
# Itr: 9	Epoch: 14	Train Acc: 0.66868	Test Acc: 0.6805
# Itr: 9	Epoch: 15	Train Acc: 0.67632	Test Acc: 0.686
# Itr: 9	Epoch: 16	Train Acc: 0.68046	Test Acc: 0.6682
# Itr: 9	Epoch: 17	Train Acc: 0.68868	Test Acc: 0.687
# Itr: 9	Epoch: 18	Train Acc: 0.6935	Test Acc: 0.6733
# Itr: 9	Epoch: 19	Train Acc: 0.69608	Test Acc: 0.6892
# Saving ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt

# %%
# !pip install kornia
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kornia
#   Downloading kornia-0.6.8-py2.py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 5.0 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from kornia) (21.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from kornia) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.8.1->kornia) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->kornia) (3.0.9)
# Installing collected packages: kornia
# Successfully installed kornia-0.6.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.5-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 5.1 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb) (6.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (7.1.2)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (2.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 75.2 MB/s
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 73.4 MB/s
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.6 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.0-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 76.5 MB/s
#   Downloading sentry_sdk-1.10.1-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 80.0 MB/s
#   Downloading sentry_sdk-1.10.0-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 68.2 MB/s
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 87.2 MB/s
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 82.8 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 78.4 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 84.9 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 79.9 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 82.3 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 85.5 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 82.4 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 84.5 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 78.9 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 81.2 MB/s
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=8901bfc12afb69cc26ae53819c5dbc09ff8777a77ef78815488c1094591c08d6
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.29 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 wandb-0.13.5

# %%
# !python distill.py --dataset=CIFAR10 --model=ConvNet --ipc=10 --syn_steps=30 --expert_epochs=2 --max_start_epoch=15 --Iteration=1000 --num_eval=2 --pix_init=real
# Out:
# CUDNN STATUS: True
# Files already downloaded and verified
# Files already downloaded and verified
# wandb: Currently logged in as: fredshi1997. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/wandb/run-20221202_020558-27h4lg8i
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run atomic-field-23
# wandb: ⭐️ View project at https://wandb.ai/fredshi1997/dip
# wandb: 🚀 View run at https://wandb.ai/fredshi1997/dip/runs/27h4lg8i
# Hyper-parameters:
#  {'dataset': 'CIFAR10', 'subset': 'imagenette', 'model': 'ConvNet', 'ipc': 10, 'eval_mode': 'S', 'num_eval': 2, 'eval_it': 100, 'epoch_eval_train': 1000, 'Iteration': 1000, 'lr_img': 1000, 'lr_lr': 1e-05, 'lr_teacher': 0.01, 'lr_init': 0.01, 'batch_real': 256, 'batch_syn': 100, 'batch_train': 256, 'pix_init': 'real', 'dsa': True, 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': 'data', 'buffer_path': './buffers', 'expert_epochs': 2, 'syn_steps': 30, 'max_start_epoch': 15, 'zca': False, 'load_all': False, 'no_aug': False, 'texture': False, 'canvas_size': 2, 'canvas_samples': 1, 'max_files': None, 'max_experts': None, 'force_save': False, 'device': 'cuda', 'im_size': [32, 32], 'dc_aug_param': None, 'dsa_param': <utils.ParamDiffAug object at 0x7f3547041100>, '_wandb': {}, 'zca_trans': None, 'distributed': False}
# Evaluation model pool:  ['ConvNet']
# BUILDING DATASET
# 100% 50000/50000 [00:10<00:00, 4653.16it/s]
# 50000it [00:00, 2479137.51it/s]
# class c = 0: 5000 real images
# class c = 1: 5000 real images
# class c = 2: 5000 real images
# class c = 3: 5000 real images
# class c = 4: 5000 real images
# class c = 5: 5000 real images
# class c = 6: 5000 real images
# class c = 7: 5000 real images
# class c = 8: 5000 real images
# class c = 9: 5000 real images
# real images channel 0, mean = -0.0000, std = 1.2211
# real images channel 1, mean = -0.0002, std = 1.2211
# real images channel 2, mean = 0.0002, std = 1.3014
# distill.py:119: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   label_syn = torch.tensor([np.ones(args.ipc,dtype=np.int_)*i for i in range(num_classes)], dtype=torch.long, requires_grad=False, device=args.device).view(-1) # [0,0,0, 1,1,1, ..., 9,9,9]
# initialize synthetic data from random real images
# [2022-12-02 02:06:12] training begins
# Expert Dir: ./buffers/CIFAR10_NO_ZCA/ConvNet
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 0
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5}
#   0% 1/1001 [00:01<27:00,  1.62s/it]/usr/local/lib/python3.8/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100% 1001/1001 [00:16<00:00, 61.87it/s]
# [2022-12-02 02:06:28] Evaluate_00: epoch = 1000 train time = 16 s train loss = 0.011921 train acc = 1.0000, test acc = 0.3376
# 100% 1001/1001 [00:14<00:00, 67.97it/s]
# [2022-12-02 02:06:43] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.014240 train acc = 1.0000, test acc = 0.3366
# Evaluate 2 random ConvNet, mean = 0.3371 std = 0.0005
# -------------------------
# [2022-12-02 02:06:45] iter = 0000, loss = 1.4877
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:07:02] iter = 0010, loss = 0.9283
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:07:19] iter = 0020, loss = 0.9683
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:07:36] iter = 0030, loss = 0.9678
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:07:52] iter = 0040, loss = 0.8221
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:08:09] iter = 0050, loss = 0.9255
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:08:26] iter = 0060, loss = 0.8058
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:08:43] iter = 0070, loss = 0.8255
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:09:00] iter = 0080, loss = 0.8160
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:09:16] iter = 0090, loss = 0.7564
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 100
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 66.15it/s]
# [2022-12-02 02:09:47] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.001922 train acc = 1.0000, test acc = 0.4956
# 100% 1001/1001 [00:15<00:00, 65.91it/s]
# [2022-12-02 02:10:02] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.007430 train acc = 1.0000, test acc = 0.4791
# Evaluate 2 random ConvNet, mean = 0.4874 std = 0.0082
# -------------------------
# [2022-12-02 02:10:04] iter = 0100, loss = 0.8456
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:10:21] iter = 0110, loss = 0.6967
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:10:38] iter = 0120, loss = 0.6722
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:10:55] iter = 0130, loss = 0.6828
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:11:11] iter = 0140, loss = 0.6915
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:11:28] iter = 0150, loss = 0.7679
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:11:45] iter = 0160, loss = 0.9484
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:12:02] iter = 0170, loss = 0.7872
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:12:19] iter = 0180, loss = 0.8611
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:12:35] iter = 0190, loss = 0.9188
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 200
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.79it/s]
# [2022-12-02 02:13:06] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000293 train acc = 1.0000, test acc = 0.5350
# 100% 1001/1001 [00:15<00:00, 65.64it/s]
# [2022-12-02 02:13:21] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000666 train acc = 1.0000, test acc = 0.5229
# Evaluate 2 random ConvNet, mean = 0.5290 std = 0.0060
# -------------------------
# [2022-12-02 02:13:23] iter = 0200, loss = 0.9019
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:13:40] iter = 0210, loss = 0.7005
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:13:57] iter = 0220, loss = 0.7232
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:14:14] iter = 0230, loss = 0.8239
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:14:31] iter = 0240, loss = 0.7972
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:14:48] iter = 0250, loss = 0.8535
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:15:05] iter = 0260, loss = 0.8283
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:15:21] iter = 0270, loss = 0.6109
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:15:38] iter = 0280, loss = 0.7130
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:15:55] iter = 0290, loss = 0.6259
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 300
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.77it/s]
# [2022-12-02 02:16:25] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000177 train acc = 1.0000, test acc = 0.5659
# 100% 1001/1001 [00:15<00:00, 65.57it/s]
# [2022-12-02 02:16:41] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000526 train acc = 1.0000, test acc = 0.5553
# Evaluate 2 random ConvNet, mean = 0.5606 std = 0.0053
# -------------------------
# [2022-12-02 02:16:43] iter = 0300, loss = 0.8453
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:17:00] iter = 0310, loss = 0.6174
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:17:17] iter = 0320, loss = 0.8954
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:17:33] iter = 0330, loss = 0.5880
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:17:50] iter = 0340, loss = 0.6562
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:18:07] iter = 0350, loss = 0.9254
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:18:24] iter = 0360, loss = 0.8274
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:18:41] iter = 0370, loss = 0.8973
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:18:58] iter = 0380, loss = 0.7917
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:19:14] iter = 0390, loss = 0.7785
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 400
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 66.05it/s]
# [2022-12-02 02:19:45] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.001564 train acc = 1.0000, test acc = 0.5563
# 100% 1001/1001 [00:15<00:00, 65.86it/s]
# [2022-12-02 02:20:00] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000267 train acc = 1.0000, test acc = 0.5608
# Evaluate 2 random ConvNet, mean = 0.5585 std = 0.0022
# -------------------------
# [2022-12-02 02:20:02] iter = 0400, loss = 0.7524
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:20:18] iter = 0410, loss = 0.9218
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:20:35] iter = 0420, loss = 0.6005
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:20:52] iter = 0430, loss = 0.6411
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:21:09] iter = 0440, loss = 0.5316
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:21:26] iter = 0450, loss = 0.6078
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:21:43] iter = 0460, loss = 0.9280
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:22:00] iter = 0470, loss = 0.8990
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:22:17] iter = 0480, loss = 0.8655
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:22:33] iter = 0490, loss = 0.8256
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 500
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 64.06it/s]
# [2022-12-02 02:23:04] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.003962 train acc = 1.0000, test acc = 0.5633
# 100% 1001/1001 [00:15<00:00, 64.23it/s]
# [2022-12-02 02:23:20] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000231 train acc = 1.0000, test acc = 0.5631
# Evaluate 2 random ConvNet, mean = 0.5632 std = 0.0001
# -------------------------
# [2022-12-02 02:23:22] iter = 0500, loss = 0.7938
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:23:39] iter = 0510, loss = 0.6294
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:23:56] iter = 0520, loss = 0.8645
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:24:13] iter = 0530, loss = 0.6126
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:24:30] iter = 0540, loss = 0.9272
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:24:47] iter = 0550, loss = 0.5386
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:25:04] iter = 0560, loss = 0.6052
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:25:21] iter = 0570, loss = 0.7889
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:25:38] iter = 0580, loss = 0.4916
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:25:55] iter = 0590, loss = 0.5173
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 600
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.49it/s]
# [2022-12-02 02:26:25] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000173 train acc = 1.0000, test acc = 0.5817
# 100% 1001/1001 [00:15<00:00, 65.61it/s]
# [2022-12-02 02:26:40] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.004030 train acc = 1.0000, test acc = 0.5771
# Evaluate 2 random ConvNet, mean = 0.5794 std = 0.0023
# -------------------------
# [2022-12-02 02:26:43] iter = 0600, loss = 0.5550
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:26:59] iter = 0610, loss = 0.6798
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:27:16] iter = 0620, loss = 0.7985
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:27:33] iter = 0630, loss = 0.7358
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:27:50] iter = 0640, loss = 0.8267
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:28:07] iter = 0650, loss = 0.9248
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:28:24] iter = 0660, loss = 0.5166
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:28:40] iter = 0670, loss = 0.7545
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:28:57] iter = 0680, loss = 0.9195
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:29:14] iter = 0690, loss = 0.9043
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 700
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.01it/s]
# [2022-12-02 02:29:45] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000279 train acc = 1.0000, test acc = 0.5715
# 100% 1001/1001 [00:15<00:00, 65.69it/s]
# [2022-12-02 02:30:00] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000142 train acc = 1.0000, test acc = 0.5765
# Evaluate 2 random ConvNet, mean = 0.5740 std = 0.0025
# -------------------------
# [2022-12-02 02:30:02] iter = 0700, loss = 0.8320
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:30:18] iter = 0710, loss = 0.5488
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:30:35] iter = 0720, loss = 0.7595
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:30:52] iter = 0730, loss = 0.7117
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:31:09] iter = 0740, loss = 0.6019
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:31:26] iter = 0750, loss = 0.6196
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:31:43] iter = 0760, loss = 0.6530
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:32:00] iter = 0770, loss = 0.5220
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:32:16] iter = 0780, loss = 0.7020
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:32:33] iter = 0790, loss = 0.8358
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 800
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.56it/s]
# [2022-12-02 02:33:04] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000567 train acc = 1.0000, test acc = 0.5864
# 100% 1001/1001 [00:15<00:00, 65.87it/s]
# [2022-12-02 02:33:19] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000284 train acc = 1.0000, test acc = 0.5722
# Evaluate 2 random ConvNet, mean = 0.5793 std = 0.0071
# -------------------------
# [2022-12-02 02:33:20] iter = 0800, loss = 0.5608
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:33:37] iter = 0810, loss = 0.9079
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:33:54] iter = 0820, loss = 0.7823
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:34:11] iter = 0830, loss = 0.7259
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:34:28] iter = 0840, loss = 0.8666
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:34:45] iter = 0850, loss = 0.6057
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:35:02] iter = 0860, loss = 0.5955
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:35:18] iter = 0870, loss = 0.5379
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:35:35] iter = 0880, loss = 0.8936
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:35:52] iter = 0890, loss = 0.9195
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 900
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.75it/s]
# [2022-12-02 02:36:23] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000174 train acc = 1.0000, test acc = 0.5711
# 100% 1001/1001 [00:15<00:00, 66.09it/s]
# [2022-12-02 02:36:38] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000166 train acc = 1.0000, test acc = 0.5662
# Evaluate 2 random ConvNet, mean = 0.5687 std = 0.0025
# -------------------------
# [2022-12-02 02:36:39] iter = 0900, loss = 0.9090
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:36:56] iter = 0910, loss = 0.7735
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:37:13] iter = 0920, loss = 0.6405
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:37:30] iter = 0930, loss = 0.8200
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:37:47] iter = 0940, loss = 0.8422
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:38:04] iter = 0950, loss = 0.5468
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:38:20] iter = 0960, loss = 0.7470
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:38:37] iter = 0970, loss = 0.7158
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:38:54] iter = 0980, loss = 0.4886
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:39:11] iter = 0990, loss = 0.7127
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 1000
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.18it/s]
# [2022-12-02 02:39:42] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000256 train acc = 1.0000, test acc = 0.5530
# 100% 1001/1001 [00:15<00:00, 65.65it/s]
# [2022-12-02 02:39:57] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000620 train acc = 1.0000, test acc = 0.5601
# Evaluate 2 random ConvNet, mean = 0.5566 std = 0.0035
# -------------------------
# [2022-12-02 02:39:59] iter = 1000, loss = 0.8571
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:     Accuracy/ConvNet ▁▅▇▇▇█████▇
# wandb:           Grand_Loss █▇▅▇▄█▃▃▆▇▂▇▃▃▂▃▃▂▇▄▄▆▆▇▄▁▃▁▁▇▆▄▆▅▁▆▇▁▇▂
# wandb: Max_Accuracy/ConvNet ▁▅▇▇▇██████
# wandb:      Max_Std/ConvNet ▁█▆▅▅▁▃▃▃▃▃
# wandb:             Progress ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          Start_Epoch ▇▇▃█▂█▁▂▆▆▂█▁▃▂▃▃▂▇▄▁▇▆▇▁▂▁▃▃█▅▅▇▅▃▆█▁▇▃
# wandb:          Std/ConvNet ▁█▆▅▃▁▃▃▇▃▄
# wandb:         Synthetic_LR ▁▁▂▂▃▄▄▅▅▅▅▆▆▆▆▇▇▇▆▇▇▇▇▇▇▇▇█████████████
# wandb:
# wandb: Run summary:
# wandb:     Accuracy/ConvNet 0.55655
# wandb:           Grand_Loss 0.85705
# wandb: Max_Accuracy/ConvNet 0.5794
# wandb:      Max_Std/ConvNet 0.0023
# wandb:             Progress 1000
# wandb:          Start_Epoch 11
# wandb:          Std/ConvNet 0.00355
# wandb:         Synthetic_LR 0.02581
# wandb:
# wandb: Synced atomic-field-23: https://wandb.ai/fredshi1997/dip/runs/27h4lg8i
# wandb: Synced 5 W&B file(s), 14 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20221202_020558-27h4lg8i/logs

# %%
import torch 
import copy
from torchvision.utils import save_image
from utils import get_dataset

class myArgs:
  def __init__(self):
    self.zca = False

args = myArgs()
channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader, loader_train_dict, class_map, class_map_inv = get_dataset('CIFAR10', 'data', 256, 'imagenette', args=args)

distilled_set_name = '/content/logged_files/CIFAR10/clear-river-13/images_900.pt'
data = torch.load(distilled_set_name)


image_syn_vis = copy.deepcopy(data.detach().cpu())
image_syn_vis[image_syn_vis<0] = 0.0
image_syn_vis[image_syn_vis>1] = 1.0
# for ch in range(channel):
#     image_syn_vis[:, ch] = image_syn_vis[:, ch] * std[ch] + mean[ch]
image_syn_vis[image_syn_vis < 0] = 0.0
image_syn_vis[image_syn_vis > 1] = 1.0
save_image(image_syn_vis, '/content/distilled_from_real_final.png', nrow=10)

# distilled_set_name = '/content/logged_files/CIFAR10/clear-river-13/images_0.pt'
# data = torch.load(distilled_set_name)


# image_syn_vis = copy.deepcopy(data.detach().cpu())
# for ch in range(channel):
#     image_syn_vis[:, ch] = image_syn_vis[:, ch] * std[ch] + mean[ch]
# image_syn_vis[image_syn_vis < 0] = 0.0
# image_syn_vis[image_syn_vis > 1] = 1.0
# save_image(image_syn_vis, '/content/distilled_from_real_initial.png', nrow=10)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# !python distill.py --dataset=CIFAR10 --model=ConvNet --ipc=10 --syn_steps=30 --expert_epochs=2 --max_start_epoch=15 --Iteration=1000 --num_eval=2 --pix_init=noise --dsa=False
# Out:
# CUDNN STATUS: True
# Files already downloaded and verified
# Files already downloaded and verified
# wandb: Currently logged in as: fredshi1997. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/wandb/run-20221202_013003-jd8mz99u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run efficient-waterfall-22
# wandb: ⭐️ View project at https://wandb.ai/fredshi1997/dip
# wandb: 🚀 View run at https://wandb.ai/fredshi1997/dip/runs/jd8mz99u
# Hyper-parameters:
#  {'dataset': 'CIFAR10', 'subset': 'imagenette', 'model': 'ConvNet', 'ipc': 10, 'eval_mode': 'S', 'num_eval': 2, 'eval_it': 100, 'epoch_eval_train': 1000, 'Iteration': 1000, 'lr_img': 1000, 'lr_lr': 1e-05, 'lr_teacher': 0.01, 'lr_init': 0.01, 'batch_real': 256, 'batch_syn': 100, 'batch_train': 256, 'pix_init': 'noise', 'dsa': True, 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': 'data', 'buffer_path': './buffers', 'expert_epochs': 2, 'syn_steps': 30, 'max_start_epoch': 15, 'zca': False, 'load_all': False, 'no_aug': False, 'texture': False, 'canvas_size': 2, 'canvas_samples': 1, 'max_files': None, 'max_experts': None, 'force_save': False, 'device': 'cuda', 'im_size': [32, 32], 'dc_aug_param': None, 'dsa_param': <utils.ParamDiffAug object at 0x7f9462542100>, '_wandb': {}, 'zca_trans': None, 'distributed': False}
# Evaluation model pool:  ['ConvNet']
# BUILDING DATASET
# 100% 50000/50000 [00:11<00:00, 4445.34it/s]
# 50000it [00:00, 2665283.92it/s]
# class c = 0: 5000 real images
# class c = 1: 5000 real images
# class c = 2: 5000 real images
# class c = 3: 5000 real images
# class c = 4: 5000 real images
# class c = 5: 5000 real images
# class c = 6: 5000 real images
# class c = 7: 5000 real images
# class c = 8: 5000 real images
# class c = 9: 5000 real images
# real images channel 0, mean = -0.0000, std = 1.2211
# real images channel 1, mean = -0.0002, std = 1.2211
# real images channel 2, mean = 0.0002, std = 1.3014
# distill.py:119: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   label_syn = torch.tensor([np.ones(args.ipc,dtype=np.int_)*i for i in range(num_classes)], dtype=torch.long, requires_grad=False, device=args.device).view(-1) # [0,0,0, 1,1,1, ..., 9,9,9]
# initialize synthetic data from random noise
# [2022-12-02 01:30:17] training begins
# Expert Dir: ./buffers/CIFAR10_NO_ZCA/ConvNet
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 0
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5}
#   0% 0/1001 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100% 1001/1001 [00:16<00:00, 62.44it/s]
# [2022-12-02 01:30:33] Evaluate_00: epoch = 1000 train time = 16 s train loss = 0.004233 train acc = 1.0000, test acc = 0.1433
# 100% 1001/1001 [00:14<00:00, 69.69it/s]
# [2022-12-02 01:30:48] Evaluate_01: epoch = 1000 train time = 14 s train loss = 0.001375 train acc = 1.0000, test acc = 0.1267
# Evaluate 2 random ConvNet, mean = 0.1350 std = 0.0083
# -------------------------
# [2022-12-02 01:30:50] iter = 0000, loss = 1.6645
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:31:06] iter = 0010, loss = 1.0510
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:31:23] iter = 0020, loss = 1.0257
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:31:39] iter = 0030, loss = 0.9892
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:31:56] iter = 0040, loss = 0.9371
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:32:13] iter = 0050, loss = 0.9646
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:32:30] iter = 0060, loss = 0.9663
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:32:47] iter = 0070, loss = 0.9678
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:33:03] iter = 0080, loss = 0.9037
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:33:20] iter = 0090, loss = 0.9751
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 100
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 64.18it/s]
# [2022-12-02 01:33:51] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000714 train acc = 1.0000, test acc = 0.2877
# 100% 1001/1001 [00:15<00:00, 65.57it/s]
# [2022-12-02 01:34:06] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.002091 train acc = 1.0000, test acc = 0.3002
# Evaluate 2 random ConvNet, mean = 0.2940 std = 0.0063
# -------------------------
# [2022-12-02 01:34:08] iter = 0100, loss = 0.9384
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:34:25] iter = 0110, loss = 0.9485
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:34:42] iter = 0120, loss = 0.8677
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:34:59] iter = 0130, loss = 1.0073
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:35:16] iter = 0140, loss = 0.9141
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:35:33] iter = 0150, loss = 0.8605
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:35:50] iter = 0160, loss = 0.8457
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:36:06] iter = 0170, loss = 0.9858
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:36:23] iter = 0180, loss = 0.9507
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:36:40] iter = 0190, loss = 0.9840
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 200
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.43it/s]
# [2022-12-02 01:37:11] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.001220 train acc = 1.0000, test acc = 0.3099
# 100% 1001/1001 [00:15<00:00, 65.14it/s]
# [2022-12-02 01:37:26] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000783 train acc = 1.0000, test acc = 0.2921
# Evaluate 2 random ConvNet, mean = 0.3010 std = 0.0089
# -------------------------
# [2022-12-02 01:37:28] iter = 0200, loss = 0.9599
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:37:45] iter = 0210, loss = 0.9643
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:38:02] iter = 0220, loss = 0.9666
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:38:19] iter = 0230, loss = 0.9796
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:38:36] iter = 0240, loss = 0.7820
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:38:53] iter = 0250, loss = 0.7510
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:39:09] iter = 0260, loss = 0.7347
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:39:26] iter = 0270, loss = 0.7762
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:39:43] iter = 0280, loss = 0.9779
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:40:00] iter = 0290, loss = 0.9361
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 300
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.51it/s]
# [2022-12-02 01:40:30] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.001720 train acc = 1.0000, test acc = 0.2849
# 100% 1001/1001 [00:15<00:00, 65.58it/s]
# [2022-12-02 01:40:46] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.002168 train acc = 1.0000, test acc = 0.3010
# Evaluate 2 random ConvNet, mean = 0.2929 std = 0.0081
# -------------------------
# [2022-12-02 01:40:47] iter = 0300, loss = 0.7487
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:41:04] iter = 0310, loss = 0.7284
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:41:21] iter = 0320, loss = 0.9460
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:41:38] iter = 0330, loss = 0.8538
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:41:55] iter = 0340, loss = 0.7367
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:42:12] iter = 0350, loss = 0.9694
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:42:29] iter = 0360, loss = 0.9302
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:42:45] iter = 0370, loss = 0.7081
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:43:02] iter = 0380, loss = 0.7172
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:43:19] iter = 0390, loss = 0.6957
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 400
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.73it/s]
# [2022-12-02 01:43:49] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000646 train acc = 1.0000, test acc = 0.3632
# 100% 1001/1001 [00:15<00:00, 65.54it/s]
# [2022-12-02 01:44:05] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000586 train acc = 1.0000, test acc = 0.3472
# Evaluate 2 random ConvNet, mean = 0.3552 std = 0.0080
# -------------------------
# [2022-12-02 01:44:07] iter = 0400, loss = 0.8171
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:44:24] iter = 0410, loss = 0.7482
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:44:41] iter = 0420, loss = 0.9536
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:44:57] iter = 0430, loss = 0.7532
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:45:14] iter = 0440, loss = 0.9796
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:45:31] iter = 0450, loss = 0.6664
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:45:48] iter = 0460, loss = 0.9464
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:46:05] iter = 0470, loss = 0.9082
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:46:22] iter = 0480, loss = 0.7215
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:46:39] iter = 0490, loss = 0.7799
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 500
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.27it/s]
# [2022-12-02 01:47:09] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.004302 train acc = 1.0000, test acc = 0.3332
# 100% 1001/1001 [00:15<00:00, 65.60it/s]
# [2022-12-02 01:47:24] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000246 train acc = 1.0000, test acc = 0.3178
# Evaluate 2 random ConvNet, mean = 0.3255 std = 0.0077
# -------------------------
# [2022-12-02 01:47:26] iter = 0500, loss = 0.9381
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:47:43] iter = 0510, loss = 0.9318
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:48:00] iter = 0520, loss = 0.6977
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:48:17] iter = 0530, loss = 0.6516
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:48:33] iter = 0540, loss = 0.7755
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:48:50] iter = 0550, loss = 0.8031
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:49:07] iter = 0560, loss = 0.7512
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:49:24] iter = 0570, loss = 0.8012
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:49:41] iter = 0580, loss = 0.7078
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:49:58] iter = 0590, loss = 0.7693
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 600
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.59it/s]
# [2022-12-02 01:50:28] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000506 train acc = 1.0000, test acc = 0.3625
# 100% 1001/1001 [00:15<00:00, 65.41it/s]
# [2022-12-02 01:50:43] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000685 train acc = 1.0000, test acc = 0.4408
# Evaluate 2 random ConvNet, mean = 0.4017 std = 0.0392
# -------------------------
# [2022-12-02 01:50:46] iter = 0600, loss = 0.9369
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:51:03] iter = 0610, loss = 0.7734
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:51:19] iter = 0620, loss = 0.6979
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:51:36] iter = 0630, loss = 0.8369
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:51:53] iter = 0640, loss = 0.8891
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:52:10] iter = 0650, loss = 0.8961
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:52:27] iter = 0660, loss = 0.9000
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:52:44] iter = 0670, loss = 0.9558
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:53:00] iter = 0680, loss = 0.6578
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:53:17] iter = 0690, loss = 0.6808
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 700
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.23it/s]
# [2022-12-02 01:53:48] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000623 train acc = 1.0000, test acc = 0.4649
# 100% 1001/1001 [00:15<00:00, 65.39it/s]
# [2022-12-02 01:54:03] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000455 train acc = 1.0000, test acc = 0.4447
# Evaluate 2 random ConvNet, mean = 0.4548 std = 0.0101
# -------------------------
# [2022-12-02 01:54:05] iter = 0700, loss = 0.8448
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:54:22] iter = 0710, loss = 0.6739
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:54:39] iter = 0720, loss = 0.9529
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:54:56] iter = 0730, loss = 0.6978
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:55:13] iter = 0740, loss = 0.8983
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:55:30] iter = 0750, loss = 0.5842
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:55:46] iter = 0760, loss = 0.9419
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:56:03] iter = 0770, loss = 0.5813
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:56:20] iter = 0780, loss = 0.7358
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:56:37] iter = 0790, loss = 0.7944
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 800
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.70it/s]
# [2022-12-02 01:57:07] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000475 train acc = 1.0000, test acc = 0.3356
# 100% 1001/1001 [00:15<00:00, 65.62it/s]
# [2022-12-02 01:57:23] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000393 train acc = 1.0000, test acc = 0.4297
# Evaluate 2 random ConvNet, mean = 0.3827 std = 0.0471
# -------------------------
# [2022-12-02 01:57:24] iter = 0800, loss = 0.8704
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:57:41] iter = 0810, loss = 0.6610
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:57:58] iter = 0820, loss = 0.6393
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:58:15] iter = 0830, loss = 0.6554
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:58:32] iter = 0840, loss = 0.7824
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 01:58:49] iter = 0850, loss = 0.9269
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:59:05] iter = 0860, loss = 0.7616
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:59:22] iter = 0870, loss = 0.8370
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:59:39] iter = 0880, loss = 0.9330
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 01:59:56] iter = 0890, loss = 0.7195
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 900
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.74it/s]
# [2022-12-02 02:00:26] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.000535 train acc = 1.0000, test acc = 0.4238
# 100% 1001/1001 [00:15<00:00, 65.94it/s]
# [2022-12-02 02:00:42] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.000504 train acc = 1.0000, test acc = 0.4117
# Evaluate 2 random ConvNet, mean = 0.4178 std = 0.0060
# -------------------------
# [2022-12-02 02:00:43] iter = 0900, loss = 0.8886
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:01:00] iter = 0910, loss = 0.5811
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:01:17] iter = 0920, loss = 0.7305
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:01:34] iter = 0930, loss = 0.6551
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:01:51] iter = 0940, loss = 0.9205
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# [2022-12-02 02:02:07] iter = 0950, loss = 0.9107
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:02:24] iter = 0960, loss = 0.7917
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:02:41] iter = 0970, loss = 0.8674
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:02:58] iter = 0980, loss = 0.6776
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_1.pt
# [2022-12-02 02:03:15] iter = 0990, loss = 0.8995
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# loading file ./buffers/CIFAR10_NO_ZCA/ConvNet/replay_buffer_0.pt
# -------------------------
# Evaluation
# model_train = ConvNet, model_eval = ConvNet, iteration = 1000
# DSA augmentation strategy:
#  color_crop_cutout_flip_scale_rotate
# DSA augmentation parameters:
#  {'aug_mode': 'S', 'prob_flip': 0.5, 'ratio_scale': 1.2, 'ratio_rotate': 15.0, 'ratio_crop_pad': 0.125, 'ratio_cutout': 0.5, 'ratio_noise': 0.05, 'brightness': 1.0, 'saturation': 2.0, 'contrast': 0.5, 'batchmode': False, 'latestseed': -1}
# 100% 1001/1001 [00:15<00:00, 65.63it/s]
# [2022-12-02 02:03:45] Evaluate_00: epoch = 1000 train time = 15 s train loss = 0.007148 train acc = 1.0000, test acc = 0.4618
# 100% 1001/1001 [00:15<00:00, 62.99it/s]
# [2022-12-02 02:04:01] Evaluate_01: epoch = 1000 train time = 15 s train loss = 0.002390 train acc = 1.0000, test acc = 0.4723
# Evaluate 2 random ConvNet, mean = 0.4670 std = 0.0053
# -------------------------
# [2022-12-02 02:04:03] iter = 1000, loss = 0.6266
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:     Accuracy/ConvNet ▁▄▄▄▆▅▇█▆▇█
# wandb:           Grand_Loss █▇█▆▇▇▅▆▅▅▄▇▇▆▆▇▄▃▃▇▆▇▇▇▆▆▄▂▃▇▇▆▆▂▄▃▂▁▅▇
# wandb: Max_Accuracy/ConvNet ▁▄▄▄▆▆▇████
# wandb:      Max_Std/ConvNet ▂▁▂▂▂▂█▂▂▂▁
# wandb:             Progress ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          Start_Epoch ▅▅▅▃▆▅▃▁▄▄▁▇▅▆▆▆▃▁▃▇▅▇▇▇▇▅▄▃▁▇▇▇▆▂▅▃▃▃▅█
# wandb:          Std/ConvNet ▂▁▂▁▁▁▇▂█▁▁
# wandb:         Synthetic_LR ▁▂▂▂▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇████████████
# wandb:
# wandb: Run summary:
# wandb:     Accuracy/ConvNet 0.46705
# wandb:           Grand_Loss 0.62656
# wandb: Max_Accuracy/ConvNet 0.46705
# wandb:      Max_Std/ConvNet 0.00525
# wandb:             Progress 1000
# wandb:          Start_Epoch 1
# wandb:          Std/ConvNet 0.00525
# wandb:         Synthetic_LR 0.02103
# wandb:
# wandb: Synced efficient-waterfall-22: https://wandb.ai/fredshi1997/dip/runs/jd8mz99u
# wandb: Synced 5 W&B file(s), 14 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20221202_013003-jd8mz99u/logs

# %%
# !zip -r /content/logged_files.zip /content/logged_files
from google.colab import files
files.download("/content/logged_files.zip")
# Out:
#   adding: content/logged_files/ (stored 0%)
#   adding: content/logged_files/CIFAR10/ (stored 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/ (stored 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter100.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter300.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_200.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_600.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter1000.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_300.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_500.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_200.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_1000.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter200.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_best.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_best.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter0.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_100.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter600.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_500.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_0.pt (deflated 65%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_600.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_0.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/vis_CIFAR10_ConvNet_10ipc_iter500.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_1000.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/labels_300.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/atomic-field-23/images_100.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/.ipynb_checkpoints/ (stored 0%)
#   adding: content/logged_files/CIFAR10/clear-river-13/ (stored 0%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_900.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_0.pt (deflated 65%)
#   adding: content/logged_files/CIFAR10/clear-river-13/labels_0.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/clear-river-13/images_900.pt (deflated 8%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/ (stored 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_700.pt (deflated 7%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter700.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter100.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_200.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_600.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter1000.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_700.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_200.pt (deflated 7%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_1000.pt (deflated 7%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter200.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_best.pt (deflated 7%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_400.pt (deflated 7%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_best.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter0.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_100.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter600.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_400.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_0.pt (deflated 7%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_600.pt (deflated 7%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_0.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/labels_1000.pt (deflated 76%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/vis_CIFAR10_ConvNet_10ipc_iter400.png (deflated 0%)
#   adding: content/logged_files/CIFAR10/efficient-waterfall-22/images_100.pt (deflated 7%)
#   adding: content/logged_files/.ipynb_checkpoints/ (stored 0%)
